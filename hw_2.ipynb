# %% [markdown]
# Рекомендательные системмы являются одними из самых популярных приложений DS. Они используются для прогнозирования предпочтений,  которые пользователь поставит какому-нибудь товару в магазине. Amazon использует их, чтобы предлагать продукты клиентам, YouTube решает какое видео воспроизводить следующим, а Facebook рекомендует посты. Существуют также рекомендательные системы для таких доменов, как рестораны, фильмы и онлайн-знакомства. Более того, для некоторых компаний, таких как Netflix, бизнес-модель и ее успех зависят от эффективности их рекомендаций. Netflix даже предложил миллион долларов в 2009 году каждому, кто сможет улучшить его систему рекомендаций на 10%.

# %% [markdown]
# Вообще говоря, рекомендательные системы могут быть поделены на 3 типа:
# * Базовый подход: предлагайте общие рекомендации каждому пользователю в зависимости от популярности фильма и / или жанра. Например, Кинопоиск 250.
# * Content-based рекомендательные системы. Эта система использует метаданные элемента, например жанр, режиссер, описание, актеры и т.д. для фильмов. Общая идея, лежащая в основе этих рекомендательных систем, заключается в том, что если человеку нравится конкретный предмет, ему также понравится предмет, похожий на него. Алгоритм будет использовать метаданные прошлых элементов пользователя. Хорошим примером может служить YouTube, где на основе вашей истории он предлагает вам новые видео, которые вы потенциально можете посмотреть.
# * Коллаборативная фильтрация. Эти системы пытаются предсказать рейтинг, который пользователь поставит элементу, на основе прошлых оценок и предпочтений других пользователей. Коллаборативной фильтрации не требуются метаданные элемента.

# %% [markdown]
# # Простые рекомендации
#
# * Сначала нужно определить метрику, по которой будем сортировать фильмы
# * Затем посчитать метрику для каждого фильма
# * Отсортировать фильмы, и выбрать топ результатов
#
# Для работы будем использовать популярный датасет MovieLens. Датасет можно скачать по [ссылке](https://www.kaggle.com/rounakbanik/the-movies-dataset).

# %%
import pandas as pd
import numpy as np

metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
metadata.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 24 columns]

# %%
metadata.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# Одна из базовых метрик - это рейтинг. Однако он не принимает во внимание популярность фильма. Таким образом, фильм с рейтингом 9 от  10 пользователей будет считаться «лучше», чем фильм с рейтингом 8,9 от 10 000 пользователей. Поэтому стоит использовать взвешенный рейтинг - учитывающий средний рейтинг и количество голосов.
#
# <img src="weighted.png">
#
# * v - количество голосов за фильм
#
# * m - минимальное количество голосов, необходимое для внесения в таблицу
#
# * R - средний рейтинг фильма
#
# * C - средний голос по всем фильмам
#
# m - гиперпараметр. Выберем для него 90 перцентиль - то есть для попадания в таблицу, у фильма должно быть больше голосов, чем у 90 процентов других фильмов.

# %%
C = metadata['vote_average'].mean()
print(C)
# Out:
# 5.618207215133889

# %%
m = metadata['vote_count'].quantile(0.90)
print(m)
# Out:
# 160.0

# %%
q_movies = metadata.copy().loc[metadata['vote_count'] >= m]
q_movies.shape
# Out:
# (4555, 24)

# %%
def weighted_rating(x, m=m, C=C):
    ###Реализуйте функцию, которая считает взвешенный рейтинг элемента###
    
    v = x['vote_count']
    R = x['vote_average']
    return v*R/(v+m) + m*C/(v+m)

# %%
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
q_movies = q_movies.sort_values('score', ascending=False)

# %%
q_movies[['title', 'vote_count', 'vote_average', 'score']].head(10)
# Out:
#                              title  vote_count  vote_average     score
# 314       The Shawshank Redemption      8358.0           8.5  8.445869
# 834                  The Godfather      6024.0           8.5  8.425439
# 10309  Dilwale Dulhania Le Jayenge       661.0           9.1  8.421453
# 12481              The Dark Knight     12269.0           8.3  8.265477
# 2843                    Fight Club      9678.0           8.3  8.256385
# 292                   Pulp Fiction      8670.0           8.3  8.251406
# 522               Schindler's List      4436.0           8.3  8.206639
# 23673                     Whiplash      4376.0           8.3  8.205404
# 5481                 Spirited Away      3968.0           8.3  8.196055
# 2211             Life Is Beautiful      3643.0           8.3  8.187171

# %% [markdown]
# Ну вот, мы построили простую рейтинговую таблицу на основании взвешенного рейтинга фильмов. Смахивает на кинопоиск, правда?

# %% [markdown]
# # Content-based рекомендации
#
# Идея content-based подхода заключается в том, чтобы по истории действий пользователя создать для него вектор его предпочтений в пространстве предметов и рекомендовать товары, близкие к этому вектору.
#
# Попробуем рекомендовать фильмы, похожие на конкретный фильм. Для этого вычислим попарные косинусные расстояния для всех фильмов на основе их сюжетных описаний и порекомендуем фильмы на основе этой метрики.

# %% [markdown]
# <img src="content.png">

# %%
metadata['overview'].head()
# Out:
# 0    Led by Woody, Andy's toys live happily in his ...
# 1    When siblings Judy and Peter discover an encha...
# 2    A family wedding reignites the ancient feud be...
# 3    Cheated on, mistreated and stepped on, the wom...
# 4    Just when George Banks has recovered from his ...
# Name: overview, dtype: object

# %% [markdown]
# Невозможно вычислить сходство между любыми двумя обзорами в их необработанном виде, поэтому вычислим векторы слов. Как следует из названия, векторы слов - это векторизованное представление слов в документе. Векторы несут семантическое значение. Например, мужчина и король будут иметь векторные представления близко друг к другу, в то время как мужчина и женщина будут иметь представления далеко друг от друга.
#
# Мы вычислим Term Frequency-Inverse Document Frequency (TF-IDF) для каждого документа. Это даст нам матрицу, в которой каждый столбец представляет слово в обзорном словаре (все слова, которые встречаются хотя бы в одном документе), а каждый столбец представляет фильм.
#
# По сути, оценка TF-IDF - это частота встречаемости слова в документе, взвешенная с уменьшением числа документов, в которых оно встречается. Это сделано для уменьшения важности слов, которые часто встречаются в обзорах сюжетов, и, следовательно, их значимости при вычислении окончательной оценки сходства.
#
# TfIdfVectorizer уже реализован в библиотеке scikit. Таким образом, нам нужно проделать следующие шаги:
#
# * импортировать Tfidf из scikit-learn
# * убрать стоп-слова, так как они не несут полезной информации
# * Замените пропущенные значения пустой строкой
# * построить матрицу TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words = 'english', dtype = np.float32) 
#Определите объект TF-IDF Vectorizer, задайте параметр, который уберет стоп-слова из английского языка

metadata['overview'] = metadata['overview'].fillna('')
#Замените все пропущенные значения в колонке пустой строкой

tfidf_matrix = tfidf.fit_transform(metadata['overview'])
#Постройте матрицу TF-IDF, вызвав метод fit-transform 

tfidf_matrix.shape
# Out:
# (45466, 75827)

# %%
tfidf.get_feature_names()[5000:5010]
# Out:
# ['avails',
#  'avaks',
#  'avalanche',
#  'avalanches',
#  'avallone',
#  'avalon',
#  'avant',
#  'avanthika',
#  'avanti',
#  'avaracious']

# %% [markdown]
# Таким образом, у нас получается 75827 различных слов в нашем наборе данных. С помощью этой матрицы мы можем вычислить оценку сходства между двумя фильмами. Мы будем использовать cosine similarity.
#
# <img src="cos.png">

# %% [markdown]
# Поскольку мы использовали TF-IDF, вычисление скалярного произведения между каждым вектором напрямую даст вам оценку косинусного сходства. Следовательно, можно использовать linear_kernel() sklearn вместо cosine_similarities(), поскольку он быстрее. Мы получим матрицу размера 45466x45466, где каждый фильм будет вектором-столбцом 1x45466.

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (45466, 45466)

# %%
cosine_sim[1]
# Out:
# array([0.01504121, 1.0000001 , 0.04681952, ..., 0.        , 0.0219864 ,
#        0.00929411], dtype=float32)

# %% [markdown]
# Нужно определить функцию, которая принимает на вход название фильма и выводит список из 10 наиболее похожих фильмов. Нужен механизм для определения индекса фильма в metadata по его названию.

# %%
indices = pd.Series(metadata.index, index=metadata['title']).drop_duplicates()

# %%
indices[:10]
# Out:
# title
# Toy Story                      0
# Jumanji                        1
# Grumpier Old Men               2
# Waiting to Exhale              3
# Father of the Bride Part II    4
# Heat                           5
# Sabrina                        6
# Tom and Huck                   7
# Sudden Death                   8
# GoldenEye                      9
# dtype: int64

# %% [markdown]
# Функция должна выполнять следующие действия:
#
# * Получить индекс фильма по его названию.
#
# * Получить список оценок косинусного сходства для этого конкретного фильма со всеми фильмами. Преобразуйте его в список кортежей, где первый элемент - это его позиция, а второй - оценка сходства.
#
# * Отсортируйте вышеупомянутый список кортежей на основе оценок сходства (второй элемент).
#
# * Получите 10 лучших элементов этого списка. Игнорируйте первый элемент, так как он относится к себе (фильм, наиболее похожий на себя - это он сам).
#
# * Верните заголовки, соответствующие индексам верхних элементов.

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    
    idx = indices[title]
    #Получите индекс по названию

    sim_scores_init = cosine_sim[idx]
    # Список оценок сходства для фильма по его индексу из матрицы оценок

    sim_scores = -np.sort(-sim_scores_init)
    #Отсортируйте массив по скорам (второй элемент)

    sim_scores_10 = sim_scores[1:11]
    # Возьмите 10 первых элементов (кроме самого фильма)
    print(sim_scores)

    movie_indices = [np.where(sim_scores_init == val)[0][0] for val in sim_scores_10]
    #Получите массив индексов этих 10 элементов 

    # Верните названия топ10 похожих фильмов
    return metadata['title'].iloc[movie_indices]

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# [1.         0.32663882 0.316211   ... 0.         0.         0.        ]
# 12481                                      The Dark Knight
# 150                                         Batman Forever
# 1328                                        Batman Returns
# 15511                           Batman: Under the Red Hood
# 585                                                 Batman
# 21194    Batman Unmasked: The Psychology of the Dark Kn...
# 9230                    Batman Beyond: Return of the Joker
# 18035                                     Batman: Year One
# 19792              Batman: The Dark Knight Returns, Part 1
# 3095                          Batman: Mask of the Phantasm
# Name: title, dtype: object

# %% [markdown]
# # Коллаборативная фильтрация

# %% [markdown]
# <img src="collaborative.png">

# %% [markdown]
# Помимо метаданных фильмов, у нас есть еще один ценный источник информации: данные о рейтингах пользователей. Наша система рекомендаций может порекомендовать фильм, похожий на «Начало (2010)», на основе оценок пользователей. Другими словами, какие еще фильмы получили аналогичные оценки других пользователей? Это был бы пример коллаборативной фильтрации item-item. Таким примером является рекомендация по типу «Пользователям, которым понравился этот элемент, понравились и другие». Мы будем исследовать набор данных ratings.csv, и сформируем векторы оценок пользователей.

# %% [markdown]
# В файле links.csv лежит маппинг разных id фильмов. В частности в ratings.csv (который мы будем использовать) используется movieId. В уже знакомом нам metadata используется tmdbId. Чтобы использовать обе таблички, добавим в metadata колонку с movieId - которая по сути является маппингом на колонку metadata['id'] с помощью links.

# %%
links = pd.read_csv('links.csv')

links = links.dropna()

links = links.drop_duplicates(subset=["tmdbId"],keep='first')

id_to_movieId = dict(links[['tmdbId','movieId']].values)

metadata['id'] = pd.to_numeric(metadata['id'],errors='coerce')

metadata = metadata.dropna(subset=['id'])

metadata['movieId'] = metadata['id'].map(id_to_movieId)

# %%
metadata['movieId']
# Out:
# 0             1.0
# 1             2.0
# 2             3.0
# 3             4.0
# 4             5.0
#            ...
# 45461    176269.0
# 45462    176271.0
# 45463    176273.0
# 45464    176275.0
# 45465    176279.0
# Name: movieId, Length: 45463, dtype: float64

# %%
#Создадим словарь отображения названия фильма в его movieId
title_to_id = dict(zip(metadata.title.tolist(), metadata.movieId.tolist()))

# %% [markdown]
# В вашем распоряжении есть два файла - ratings.csv и ratings_small.csv. Второй файлик содержит намного меньше информации, но для быстрой работы давайте использовать его (хотя качество, конечно же, получится хуже). При желании вы можете обучить модель на полном файле рейтингов (ratings.csv).

# %%
ratings = pd.read_csv('ratings_small.csv')

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
ratings_grouped_by = ratings.groupby('userId')['rating'].agg(['count']).reset_index()
m = 50
ratings_grouped_by = ratings_grouped_by.copy().loc[ratings_grouped_by['count'] >= m]

ratings_f = ratings.copy().loc[ratings['userId'].isin(ratings_grouped_by['userId'].values)]
                                                              #Отфильтруйте таблицу - оставьте только те userId, которые проставили не менее 50 оценок

ratings_pivot = pd.pivot_table(ratings_f, values='rating', index=['movieId'], columns=['userId'])
                                                             #Создайте pivot таблицу из отфильтрованной ratings_f. Индексы - фильмы, колонки - пользователи, значения - рейтинг

# %%
ratings_pivot.head()
# Out:
# userId   2    3    4    5    7    8    12   13   15   17   ...  655  656  658  \
# movieId                                                    ...
# 1        NaN  NaN  NaN  NaN  3.0  NaN  NaN  5.0  2.0  NaN  ...  NaN  NaN  NaN
# 2        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.0  NaN  ...  4.0  NaN  NaN
# 3        NaN  NaN  NaN  4.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 4        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 5        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  4.5  NaN  ...  NaN  NaN  NaN
#
# userId   659  660  662  664  665  667  671
# movieId
# 1        NaN  2.5  NaN  3.5  NaN  NaN  5.0
# 2        NaN  NaN  5.0  NaN  3.0  NaN  NaN
# 3        NaN  NaN  NaN  NaN  3.0  NaN  NaN
# 4        NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5        NaN  NaN  NaN  NaN  3.0  NaN  NaN
#
# [5 rows x 427 columns]

# %% [markdown]
# ##### Matrix Factorization.
#
# Что ж, теперь в нашем распоряжении есть матрица оценок пользователь-айтем. Из математики мы знаем, что любую матрицу можно разложить на произведение трех матриц - например алгоритмом SVD. Но матрицы оценок очень разрежены, 99 % — обычное дело. А SVD не знает, что такое пропуски. Заполнять их средним значением не очень хочется. И в целом, нас не очень интересует матрица сингулярных значений — мы просто хотим получить скрытое представление пользователей и предметов, которое при перемножении будет приближать истинный рейтинг. Можно сразу раскладывать на две матрицы.

# %% [markdown]
# <img src="svd.png">

# %% [markdown]
# Что же делать с пропусками? Забить на них. Оказалось, что можно успешно обучать приближать рейтинги по метрике RMSE с помощью SGD или ALS, вообще игнорируя пропуски. Первый такой алгоритм — Funk SVD, который придумали в 2006 году в ходе решения соревнования от Netflix.
#
# Но например в задаче рекомендации товаров, мы имеем уже не матрицу оценок, а матрицу некоторых событий. Она будет состоять в основном из нулей и единичек, иногда каких то чисел побольше. Таким образом, у  нас будут присутствовать только положительные примеры. У нас нет примеров товаров, которые человек никогда не купит - получается мы не можем понять, человек не видел товар или он ему не нравится. Таким образом фидбэк от пользователя может быть двух типов:
#
# * Explicit feedback - есть положительные и отрицательные примеры.
# * Implicit feedback - есть только положительные.
#
# Так вот, забить на пропуски получается только в случае задачи explicit feedback. В случае implicit можно заполнить пропущенные значения например нулем, и настроить веса в оптимизируемом функционале - низкие для нулей, и повыше для ненулевых ячеек.

# %% [markdown]
# Для того чтобы лучше разобраться в математике, можно прочитать например вот [этот пост](https://habr.com/ru/company/yandex/blog/241455/).

# %% [markdown]
# <img src="netflix.png">

# %% [markdown]
# Алгоритм SVD реализован в библиотеке [Surprise](https://github.com/NicolasHug/Surprise). Далее мы обучим модель и используем ее для прогнозирования рейтингов фильмов, которые данный пользователь, например с 𝑖𝑑 = 2, еще не получил оценку.

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /Users/dmitrij/opt/anaconda3/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: six>=1.10.0 in /Users/dmitrij/opt/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (1.14.0)
# Requirement already satisfied: joblib>=0.11 in /Users/dmitrij/opt/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (0.14.1)
# Requirement already satisfied: scipy>=1.0.0 in /Users/dmitrij/opt/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (1.4.1)
# Requirement already satisfied: numpy>=1.11.2 in /Users/dmitrij/opt/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (1.18.1)

# %%
from surprise import Dataset, Reader, SVD, accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings_f[['userId','movieId','rating']], reader)

trainset, testset = train_test_split(data, test_size=.25)
algorithm = SVD()
algorithm.fit(trainset)
predictions = algorithm.test(testset)

accuracy.rmse(predictions)
# Out:
# RMSE: 0.8927
# 0.8927469290001232

# %%
predictions
# Out:
# [Prediction(uid=234, iid=45928, r_ui=4.0, est=3.5148068438479725, details={'was_impossible': False}),
#  Prediction(uid=159, iid=2858, r_ui=4.5, est=4.266918042209753, details={'was_impossible': False}),
#  Prediction(uid=662, iid=586, r_ui=4.0, est=3.336236307354778, details={'was_impossible': False}),
#  Prediction(uid=311, iid=6428, r_ui=3.0, est=3.1184041120633714, details={'was_impossible': False}),
#  Prediction(uid=19, iid=179, r_ui=2.0, est=3.297386522091298, details={'was_impossible': False}),
#  Prediction(uid=150, iid=74458, r_ui=4.0, est=3.297489034215883, details={'was_impossible': False}),
#  Prediction(uid=254, iid=466, r_ui=3.0, est=3.2302856015555808, details={'was_impossible': False}),
#  Prediction(uid=201, iid=736, r_ui=4.0, est=3.5852650094754663, details={'was_impossible': False}),
#  Prediction(uid=287, iid=480, r_ui=5.0, est=4.740161562768477, details={'was_impossible': False}),
#  Prediction(uid=542, iid=74789, r_ui=2.5, est=3.4678059113234974, details={'was_impossible': False}),
#  Prediction(uid=73, iid=111759, r_ui=4.0, est=3.5507079189995543, details={'was_impossible': False}),
#  Prediction(uid=596, iid=3556, r_ui=4.5, est=3.338020252412746, details={'was_impossible': False}),
#  Prediction(uid=254, iid=253, r_ui=3.0, est=3.463616419020345, details={'was_impossible': False}),
#  Prediction(uid=308, iid=366, r_ui=3.0, est=3.2121431306086197, details={'was_impossible': False}),
#  Prediction(uid=575, iid=4795, r_ui=4.0, est=3.382870855087833, details={'was_impossible': False}),
#  Prediction(uid=137, iid=1537, r_ui=3.0, est=3.901230870338241, details={'was_impossible': False}),
#  Prediction(uid=344, iid=442, r_ui=3.0, est=3.083812620269552, details={'was_impossible': False}),
#  Prediction(uid=344, iid=541, r_ui=5.0, est=4.390226064576389, details={'was_impossible': False}),
#  Prediction(uid=361, iid=7, r_ui=3.0, est=3.5765852897499855, details={'was_impossible': False}),
#  Prediction(uid=547, iid=6271, r_ui=4.5, est=3.3561390104332407, details={'was_impossible': False}),
#  Prediction(uid=471, iid=59615, r_ui=3.5, est=3.0959786070904123, details={'was_impossible': False}),
#  Prediction(uid=30, iid=2804, r_ui=4.0, est=4.385069540466814, details={'was_impossible': False}),
#  Prediction(uid=235, iid=48, r_ui=3.0, est=3.778171086508908, details={'was_impossible': False}),
#  Prediction(uid=457, iid=1464, r_ui=4.0, est=2.2907132444108074, details={'was_impossible': False}),
#  Prediction(uid=119, iid=1834, r_ui=3.0, est=3.7458382420327934, details={'was_impossible': False}),
#  Prediction(uid=346, iid=1097, r_ui=2.0, est=3.5942066433726834, details={'was_impossible': False}),
#  Prediction(uid=275, iid=64614, r_ui=4.0, est=4.6056222109731575, details={'was_impossible': False}),
#  Prediction(uid=654, iid=3863, r_ui=3.5, est=3.963050142242596, details={'was_impossible': False}),
#  Prediction(uid=615, iid=4865, r_ui=2.5, est=3.745034153068982, details={'was_impossible': False}),
#  Prediction(uid=500, iid=2321, r_ui=3.5, est=2.8670248161666683, details={'was_impossible': False}),
#  Prediction(uid=5, iid=6218, r_ui=3.5, est=4.024849781843506, details={'was_impossible': False}),
#  Prediction(uid=624, iid=818, r_ui=3.5, est=2.300748472057816, details={'was_impossible': False}),
#  Prediction(uid=564, iid=2640, r_ui=4.0, est=3.5504748601571765, details={'was_impossible': False}),
#  Prediction(uid=362, iid=2324, r_ui=4.5, est=4.113276801535493, details={'was_impossible': False}),
#  Prediction(uid=294, iid=3082, r_ui=3.5, est=3.3500888965285607, details={'was_impossible': False}),
#  Prediction(uid=417, iid=1610, r_ui=4.0, est=4.1418355210710995, details={'was_impossible': False}),
#  Prediction(uid=361, iid=839, r_ui=5.0, est=3.5287231818798133, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2194, r_ui=5.0, est=4.910879981684566, details={'was_impossible': False}),
#  Prediction(uid=279, iid=316, r_ui=3.0, est=3.118746716708539, details={'was_impossible': False}),
#  Prediction(uid=457, iid=128520, r_ui=1.0, est=2.365413896533886, details={'was_impossible': False}),
#  Prediction(uid=224, iid=335, r_ui=4.0, est=3.959092322088741, details={'was_impossible': False}),
#  Prediction(uid=564, iid=2336, r_ui=3.0, est=3.3753037352603728, details={'was_impossible': False}),
#  Prediction(uid=232, iid=778, r_ui=5.0, est=4.50862106406516, details={'was_impossible': False}),
#  Prediction(uid=486, iid=52245, r_ui=3.0, est=3.458059077379779, details={'was_impossible': False}),
#  Prediction(uid=380, iid=6936, r_ui=4.0, est=3.508223018993954, details={'was_impossible': False}),
#  Prediction(uid=19, iid=4970, r_ui=4.0, est=3.472735932245091, details={'was_impossible': False}),
#  Prediction(uid=232, iid=412, r_ui=5.0, est=3.808685309876616, details={'was_impossible': False}),
#  Prediction(uid=580, iid=3317, r_ui=4.0, est=3.704185578115157, details={'was_impossible': False}),
#  Prediction(uid=86, iid=34, r_ui=3.0, est=3.8027368527201673, details={'was_impossible': False}),
#  Prediction(uid=621, iid=6104, r_ui=4.5, est=3.7290786863942045, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1305, r_ui=4.5, est=3.8510449156064284, details={'was_impossible': False}),
#  Prediction(uid=352, iid=1356, r_ui=4.5, est=3.5395128331714636, details={'was_impossible': False}),
#  Prediction(uid=250, iid=3408, r_ui=4.5, est=4.1522324006973275, details={'was_impossible': False}),
#  Prediction(uid=189, iid=3578, r_ui=5.0, est=3.7426851536662875, details={'was_impossible': False}),
#  Prediction(uid=624, iid=1227, r_ui=5.0, est=3.532034043024503, details={'was_impossible': False}),
#  Prediction(uid=427, iid=3594, r_ui=3.0, est=3.7020974301749963, details={'was_impossible': False}),
#  Prediction(uid=342, iid=1954, r_ui=5.0, est=4.179508978499692, details={'was_impossible': False}),
#  Prediction(uid=407, iid=253, r_ui=3.0, est=3.8899499004417435, details={'was_impossible': False}),
#  Prediction(uid=380, iid=90719, r_ui=3.5, est=3.2589995869822572, details={'was_impossible': False}),
#  Prediction(uid=15, iid=69406, r_ui=1.0, est=3.1131606317948894, details={'was_impossible': False}),
#  Prediction(uid=537, iid=1247, r_ui=5.0, est=4.4695248419940965, details={'was_impossible': False}),
#  Prediction(uid=384, iid=2428, r_ui=3.0, est=2.550488191115997, details={'was_impossible': False}),
#  Prediction(uid=468, iid=3253, r_ui=2.5, est=2.990552316310001, details={'was_impossible': False}),
#  Prediction(uid=285, iid=3489, r_ui=2.0, est=2.880631174029028, details={'was_impossible': False}),
#  Prediction(uid=362, iid=71464, r_ui=4.5, est=3.4509865379816382, details={'was_impossible': False}),
#  Prediction(uid=615, iid=104879, r_ui=4.5, est=3.531555830931905, details={'was_impossible': False}),
#  Prediction(uid=212, iid=3300, r_ui=3.5, est=3.093976329431441, details={'was_impossible': False}),
#  Prediction(uid=564, iid=1391, r_ui=4.0, est=3.0415341585639633, details={'was_impossible': False}),
#  Prediction(uid=520, iid=1784, r_ui=3.5, est=3.9088818389069715, details={'was_impossible': False}),
#  Prediction(uid=418, iid=2617, r_ui=4.0, est=3.394582554328558, details={'was_impossible': False}),
#  Prediction(uid=270, iid=116823, r_ui=3.5, est=3.3090785863112253, details={'was_impossible': False}),
#  Prediction(uid=388, iid=26729, r_ui=4.5, est=4.067211650902451, details={'was_impossible': False}),
#  Prediction(uid=510, iid=2313, r_ui=2.0, est=3.2934429140531782, details={'was_impossible': False}),
#  Prediction(uid=534, iid=163, r_ui=4.0, est=3.4937382834813495, details={'was_impossible': False}),
#  Prediction(uid=48, iid=69757, r_ui=4.5, est=3.4912727227579645, details={'was_impossible': False}),
#  Prediction(uid=90, iid=783, r_ui=3.0, est=3.804998572187922, details={'was_impossible': False}),
#  Prediction(uid=664, iid=92420, r_ui=3.5, est=3.8444700048653613, details={'was_impossible': False}),
#  Prediction(uid=294, iid=6723, r_ui=3.5, est=3.5719114113245354, details={'was_impossible': False}),
#  Prediction(uid=111, iid=3967, r_ui=3.5, est=3.7508760821402647, details={'was_impossible': False}),
#  Prediction(uid=607, iid=3948, r_ui=3.5, est=3.666572333786146, details={'was_impossible': False}),
#  Prediction(uid=102, iid=3700, r_ui=4.0, est=3.8302095374540515, details={'was_impossible': False}),
#  Prediction(uid=30, iid=2000, r_ui=4.0, est=3.831998250447654, details={'was_impossible': False}),
#  Prediction(uid=525, iid=4896, r_ui=4.0, est=3.5554440983019466, details={'was_impossible': False}),
#  Prediction(uid=595, iid=1188, r_ui=5.0, est=3.331181414083156, details={'was_impossible': False}),
#  Prediction(uid=321, iid=1713, r_ui=4.0, est=2.8230501641541412, details={'was_impossible': False}),
#  Prediction(uid=230, iid=48774, r_ui=3.0, est=4.270410859502553, details={'was_impossible': False}),
#  Prediction(uid=615, iid=99007, r_ui=3.5, est=3.408098234720492, details={'was_impossible': False}),
#  Prediction(uid=434, iid=913, r_ui=5.0, est=4.334711125935731, details={'was_impossible': False}),
#  Prediction(uid=288, iid=357, r_ui=5.0, est=3.9718098058148894, details={'was_impossible': False}),
#  Prediction(uid=575, iid=5079, r_ui=3.0, est=3.312641939978507, details={'was_impossible': False}),
#  Prediction(uid=575, iid=2146, r_ui=3.0, est=3.232253451685186, details={'was_impossible': False}),
#  Prediction(uid=442, iid=780, r_ui=3.5, est=3.936118351553544, details={'was_impossible': False}),
#  Prediction(uid=285, iid=1753, r_ui=3.0, est=2.917788245323268, details={'was_impossible': False}),
#  Prediction(uid=472, iid=2463, r_ui=4.0, est=3.9198117914657375, details={'was_impossible': False}),
#  Prediction(uid=537, iid=1084, r_ui=4.0, est=4.206588606635044, details={'was_impossible': False}),
#  Prediction(uid=467, iid=2599, r_ui=4.0, est=4.201371953420828, details={'was_impossible': False}),
#  Prediction(uid=177, iid=1644, r_ui=5.0, est=3.346945029559162, details={'was_impossible': False}),
#  Prediction(uid=73, iid=87306, r_ui=4.0, est=3.009182711011426, details={'was_impossible': False}),
#  Prediction(uid=175, iid=2858, r_ui=4.0, est=4.183655992899083, details={'was_impossible': False}),
#  Prediction(uid=468, iid=7044, r_ui=3.0, est=2.830648018053281, details={'was_impossible': False}),
#  Prediction(uid=119, iid=1754, r_ui=3.0, est=3.5845811574949993, details={'was_impossible': False}),
#  Prediction(uid=574, iid=55820, r_ui=4.5, est=4.145630334087369, details={'was_impossible': False}),
#  Prediction(uid=553, iid=88140, r_ui=4.5, est=3.9069748419990913, details={'was_impossible': False}),
#  Prediction(uid=547, iid=2890, r_ui=5.0, est=3.6905300476946747, details={'was_impossible': False}),
#  Prediction(uid=548, iid=45, r_ui=3.0, est=3.2348192046837174, details={'was_impossible': False}),
#  Prediction(uid=537, iid=1253, r_ui=5.0, est=4.043913744984134, details={'was_impossible': False}),
#  Prediction(uid=599, iid=54503, r_ui=4.5, est=4.035313346772876, details={'was_impossible': False}),
#  Prediction(uid=457, iid=110, r_ui=3.0, est=3.1762823041275445, details={'was_impossible': False}),
#  Prediction(uid=548, iid=785, r_ui=3.0, est=2.7748038767956973, details={'was_impossible': False}),
#  Prediction(uid=213, iid=5952, r_ui=4.0, est=3.437756672718844, details={'was_impossible': False}),
#  Prediction(uid=294, iid=31685, r_ui=4.0, est=3.407803102094201, details={'was_impossible': False}),
#  Prediction(uid=105, iid=3157, r_ui=3.0, est=2.7760920609351363, details={'was_impossible': False}),
#  Prediction(uid=615, iid=100163, r_ui=2.0, est=3.5911713537333, details={'was_impossible': False}),
#  Prediction(uid=241, iid=367, r_ui=3.0, est=2.639489669077541, details={'was_impossible': False}),
#  Prediction(uid=73, iid=30812, r_ui=3.5, est=3.554203954025823, details={'was_impossible': False}),
#  Prediction(uid=102, iid=1923, r_ui=3.0, est=3.7328022855305685, details={'was_impossible': False}),
#  Prediction(uid=281, iid=26131, r_ui=3.5, est=3.873976556271339, details={'was_impossible': False}),
#  Prediction(uid=664, iid=74545, r_ui=4.0, est=3.460445845905144, details={'was_impossible': False}),
#  Prediction(uid=169, iid=274, r_ui=2.0, est=3.8464087181849713, details={'was_impossible': False}),
#  Prediction(uid=564, iid=1312, r_ui=5.0, est=3.5396499874829654, details={'was_impossible': False}),
#  Prediction(uid=185, iid=4941, r_ui=2.0, est=3.1009004049209814, details={'was_impossible': False}),
#  Prediction(uid=664, iid=33679, r_ui=3.0, est=3.6340303438973143, details={'was_impossible': False}),
#  Prediction(uid=245, iid=588, r_ui=1.0, est=4.201655133398007, details={'was_impossible': False}),
#  Prediction(uid=23, iid=7265, r_ui=4.0, est=3.5613302224911774, details={'was_impossible': False}),
#  Prediction(uid=441, iid=5446, r_ui=4.0, est=3.9159643227692404, details={'was_impossible': False}),
#  Prediction(uid=388, iid=5013, r_ui=5.0, est=3.8888749210237283, details={'was_impossible': False}),
#  Prediction(uid=199, iid=8874, r_ui=4.0, est=3.9492536377568537, details={'was_impossible': False}),
#  Prediction(uid=569, iid=931, r_ui=4.0, est=3.7690386533444724, details={'was_impossible': False}),
#  Prediction(uid=119, iid=904, r_ui=5.0, est=3.761649284482635, details={'was_impossible': False}),
#  Prediction(uid=328, iid=4406, r_ui=3.5, est=3.3592060437043982, details={'was_impossible': False}),
#  Prediction(uid=434, iid=1193, r_ui=3.0, est=4.396405070541869, details={'was_impossible': False}),
#  Prediction(uid=572, iid=47099, r_ui=4.0, est=3.7913498367758627, details={'was_impossible': False}),
#  Prediction(uid=653, iid=2978, r_ui=3.0, est=3.991092659391304, details={'was_impossible': False}),
#  Prediction(uid=242, iid=1270, r_ui=5.0, est=4.9856715609384175, details={'was_impossible': False}),
#  Prediction(uid=587, iid=1178, r_ui=4.0, est=4.47406003701715, details={'was_impossible': False}),
#  Prediction(uid=339, iid=99114, r_ui=2.5, est=4.256471261503548, details={'was_impossible': False}),
#  Prediction(uid=353, iid=597, r_ui=1.5, est=2.5198797152417827, details={'was_impossible': False}),
#  Prediction(uid=452, iid=3999, r_ui=1.5, est=2.6935557760869107, details={'was_impossible': False}),
#  Prediction(uid=312, iid=1244, r_ui=4.0, est=3.96969599287326, details={'was_impossible': False}),
#  Prediction(uid=551, iid=1083, r_ui=3.0, est=3.4259238195862607, details={'was_impossible': False}),
#  Prediction(uid=294, iid=7161, r_ui=3.0, est=3.428558575325866, details={'was_impossible': False}),
#  Prediction(uid=15, iid=2340, r_ui=2.0, est=1.8896119305789072, details={'was_impossible': False}),
#  Prediction(uid=15, iid=61323, r_ui=1.0, est=2.7709508570884562, details={'was_impossible': False}),
#  Prediction(uid=242, iid=2424, r_ui=5.0, est=4.333499634420157, details={'was_impossible': False}),
#  Prediction(uid=621, iid=2502, r_ui=4.5, est=4.099301118146414, details={'was_impossible': False}),
#  Prediction(uid=295, iid=5349, r_ui=5.0, est=3.8639211074193773, details={'was_impossible': False}),
#  Prediction(uid=452, iid=2926, r_ui=3.0, est=3.8743818651035458, details={'was_impossible': False}),
#  Prediction(uid=615, iid=3863, r_ui=3.5, est=3.4149308050272777, details={'was_impossible': False}),
#  Prediction(uid=624, iid=8623, r_ui=3.5, est=2.9696706841601634, details={'was_impossible': False}),
#  Prediction(uid=596, iid=7458, r_ui=3.5, est=3.2733641938746625, details={'was_impossible': False}),
#  Prediction(uid=382, iid=60069, r_ui=3.0, est=3.1640324828053243, details={'was_impossible': False}),
#  Prediction(uid=480, iid=56782, r_ui=3.5, est=4.247752186917663, details={'was_impossible': False}),
#  Prediction(uid=159, iid=457, r_ui=3.0, est=3.6280273238068936, details={'was_impossible': False}),
#  Prediction(uid=597, iid=1238, r_ui=4.0, est=4.248718132772682, details={'was_impossible': False}),
#  Prediction(uid=380, iid=91974, r_ui=3.0, est=3.1963857853259263, details={'was_impossible': False}),
#  Prediction(uid=481, iid=1097, r_ui=4.5, est=4.252378379992143, details={'was_impossible': False}),
#  Prediction(uid=537, iid=923, r_ui=4.0, est=4.253490181979771, details={'was_impossible': False}),
#  Prediction(uid=396, iid=1079, r_ui=4.0, est=3.792797703894804, details={'was_impossible': False}),
#  Prediction(uid=509, iid=1250, r_ui=4.0, est=4.056074261378093, details={'was_impossible': False}),
#  Prediction(uid=70, iid=880, r_ui=4.0, est=3.2951833907463324, details={'was_impossible': False}),
#  Prediction(uid=493, iid=258, r_ui=3.0, est=2.9241568525410377, details={'was_impossible': False}),
#  Prediction(uid=460, iid=1266, r_ui=4.0, est=3.886357429711988, details={'was_impossible': False}),
#  Prediction(uid=574, iid=2683, r_ui=2.5, est=3.2453170134727145, details={'was_impossible': False}),
#  Prediction(uid=529, iid=2268, r_ui=4.0, est=3.6374919024218446, details={'was_impossible': False}),
#  Prediction(uid=405, iid=3379, r_ui=4.5, est=3.624474712124554, details={'was_impossible': False}),
#  Prediction(uid=509, iid=3130, r_ui=4.0, est=2.4728211965205453, details={'was_impossible': False}),
#  Prediction(uid=514, iid=162, r_ui=5.0, est=4.0203784720486375, details={'was_impossible': False}),
#  Prediction(uid=452, iid=8128, r_ui=4.5, est=3.1452623000142546, details={'was_impossible': False}),
#  Prediction(uid=412, iid=364, r_ui=4.0, est=3.299115776330095, details={'was_impossible': False}),
#  Prediction(uid=161, iid=608, r_ui=3.0, est=4.111973685587938, details={'was_impossible': False}),
#  Prediction(uid=547, iid=1035, r_ui=5.0, est=2.9799692874630033, details={'was_impossible': False}),
#  Prediction(uid=164, iid=1722, r_ui=3.5, est=3.2092930458351057, details={'was_impossible': False}),
#  Prediction(uid=575, iid=3552, r_ui=4.0, est=2.9791517196094213, details={'was_impossible': False}),
#  Prediction(uid=652, iid=293, r_ui=4.0, est=4.837581417504911, details={'was_impossible': False}),
#  Prediction(uid=575, iid=1225, r_ui=3.0, est=3.935578121269461, details={'was_impossible': False}),
#  Prediction(uid=588, iid=253, r_ui=2.0, est=3.413945155487131, details={'was_impossible': False}),
#  Prediction(uid=387, iid=141, r_ui=4.0, est=3.771496960093447, details={'was_impossible': False}),
#  Prediction(uid=213, iid=1438, r_ui=2.0, est=2.3427214129352922, details={'was_impossible': False}),
#  Prediction(uid=461, iid=1263, r_ui=3.0, est=3.616113927983598, details={'was_impossible': False}),
#  Prediction(uid=627, iid=1485, r_ui=1.0, est=2.597553720147798, details={'was_impossible': False}),
#  Prediction(uid=612, iid=349, r_ui=3.0, est=3.486359246201756, details={'was_impossible': False}),
#  Prediction(uid=30, iid=5391, r_ui=4.0, est=3.835268736950723, details={'was_impossible': False}),
#  Prediction(uid=102, iid=904, r_ui=5.0, est=4.411995699633145, details={'was_impossible': False}),
#  Prediction(uid=452, iid=24, r_ui=2.0, est=2.969422834469973, details={'was_impossible': False}),
#  Prediction(uid=562, iid=3949, r_ui=3.0, est=4.219511525056735, details={'was_impossible': False}),
#  Prediction(uid=311, iid=1187, r_ui=1.5, est=2.8776207762173325, details={'was_impossible': False}),
#  Prediction(uid=41, iid=208, r_ui=4.0, est=3.139727391837325, details={'was_impossible': False}),
#  Prediction(uid=433, iid=1923, r_ui=3.0, est=3.7365426217901607, details={'was_impossible': False}),
#  Prediction(uid=564, iid=344, r_ui=3.0, est=3.5189352770382447, details={'was_impossible': False}),
#  Prediction(uid=294, iid=901, r_ui=3.5, est=3.688135522957533, details={'was_impossible': False}),
#  Prediction(uid=478, iid=72998, r_ui=4.0, est=3.9800731638496267, details={'was_impossible': False}),
#  Prediction(uid=15, iid=1276, r_ui=2.5, est=3.235943143497864, details={'was_impossible': False}),
#  Prediction(uid=523, iid=6711, r_ui=4.0, est=4.0172914229971415, details={'was_impossible': False}),
#  Prediction(uid=425, iid=8784, r_ui=0.5, est=3.459066350996414, details={'was_impossible': False}),
#  Prediction(uid=346, iid=2762, r_ui=1.0, est=3.473158198690367, details={'was_impossible': False}),
#  Prediction(uid=384, iid=5609, r_ui=3.0, est=3.0362469042138187, details={'was_impossible': False}),
#  Prediction(uid=350, iid=3869, r_ui=4.0, est=3.4635873931967254, details={'was_impossible': False}),
#  Prediction(uid=480, iid=1729, r_ui=5.0, est=4.050500895714957, details={'was_impossible': False}),
#  Prediction(uid=603, iid=1025, r_ui=5.0, est=3.807151694157187, details={'was_impossible': False}),
#  Prediction(uid=344, iid=529, r_ui=4.0, est=3.8905156653306032, details={'was_impossible': False}),
#  Prediction(uid=96, iid=2248, r_ui=3.0, est=4.0471952650373995, details={'was_impossible': False}),
#  Prediction(uid=386, iid=6242, r_ui=4.0, est=3.0162488897371524, details={'was_impossible': False}),
#  Prediction(uid=418, iid=592, r_ui=3.0, est=3.6212034512685136, details={'was_impossible': False}),
#  Prediction(uid=607, iid=1968, r_ui=3.5, est=4.073814087303495, details={'was_impossible': False}),
#  Prediction(uid=185, iid=2571, r_ui=5.0, est=4.171902907326503, details={'was_impossible': False}),
#  Prediction(uid=580, iid=32031, r_ui=3.0, est=3.1249487157002274, details={'was_impossible': False}),
#  Prediction(uid=656, iid=779, r_ui=4.0, est=4.374219294567801, details={'was_impossible': False}),
#  Prediction(uid=596, iid=3499, r_ui=3.5, est=3.8768748666519737, details={'was_impossible': False}),
#  Prediction(uid=402, iid=1028, r_ui=4.5, est=3.948666064607141, details={'was_impossible': False}),
#  Prediction(uid=587, iid=37733, r_ui=3.5, est=3.8345987104658965, details={'was_impossible': False}),
#  Prediction(uid=665, iid=450, r_ui=4.0, est=3.1399602444351236, details={'was_impossible': False}),
#  Prediction(uid=30, iid=2015, r_ui=3.0, est=3.939685475901493, details={'was_impossible': False}),
#  Prediction(uid=195, iid=3098, r_ui=3.0, est=3.2800893301020952, details={'was_impossible': False}),
#  Prediction(uid=580, iid=59784, r_ui=2.5, est=3.694567446955832, details={'was_impossible': False}),
#  Prediction(uid=475, iid=4993, r_ui=5.0, est=4.028324188623797, details={'was_impossible': False}),
#  Prediction(uid=346, iid=1214, r_ui=3.5, est=3.6255903939950254, details={'was_impossible': False}),
#  Prediction(uid=294, iid=969, r_ui=3.5, est=4.341421803309049, details={'was_impossible': False}),
#  Prediction(uid=73, iid=4299, r_ui=2.5, est=3.8092869876950375, details={'was_impossible': False}),
#  Prediction(uid=533, iid=1726, r_ui=3.0, est=3.2737322529423776, details={'was_impossible': False}),
#  Prediction(uid=516, iid=357, r_ui=4.0, est=3.883172980502567, details={'was_impossible': False}),
#  Prediction(uid=608, iid=2401, r_ui=4.0, est=3.643288423406626, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2997, r_ui=4.5, est=4.141170928445557, details={'was_impossible': False}),
#  Prediction(uid=664, iid=22, r_ui=3.0, est=3.657837005281185, details={'was_impossible': False}),
#  Prediction(uid=19, iid=1, r_ui=3.0, est=3.9726291424120213, details={'was_impossible': False}),
#  Prediction(uid=394, iid=1240, r_ui=3.0, est=2.4908435868517547, details={'was_impossible': False}),
#  Prediction(uid=488, iid=319, r_ui=4.5, est=3.7175978263946012, details={'was_impossible': False}),
#  Prediction(uid=250, iid=91529, r_ui=5.0, est=4.4705415854816355, details={'was_impossible': False}),
#  Prediction(uid=547, iid=1148, r_ui=2.0, est=3.7343881888087567, details={'was_impossible': False}),
#  Prediction(uid=306, iid=3247, r_ui=4.0, est=3.377061223422923, details={'was_impossible': False}),
#  Prediction(uid=15, iid=94864, r_ui=1.5, est=2.288691081009503, details={'was_impossible': False}),
#  Prediction(uid=128, iid=93, r_ui=1.0, est=3.3697804668319664, details={'was_impossible': False}),
#  Prediction(uid=605, iid=230, r_ui=3.0, est=3.2633359387034426, details={'was_impossible': False}),
#  Prediction(uid=603, iid=1073, r_ui=3.0, est=3.9926667221203234, details={'was_impossible': False}),
#  Prediction(uid=457, iid=7153, r_ui=0.5, est=2.6889645109997455, details={'was_impossible': False}),
#  Prediction(uid=17, iid=3386, r_ui=4.0, est=3.7765969757697464, details={'was_impossible': False}),
#  Prediction(uid=214, iid=2529, r_ui=3.0, est=3.9710041854929665, details={'was_impossible': False}),
#  Prediction(uid=452, iid=6337, r_ui=4.0, est=3.1540945577898616, details={'was_impossible': False}),
#  Prediction(uid=547, iid=2245, r_ui=4.5, est=2.905867668658594, details={'was_impossible': False}),
#  Prediction(uid=187, iid=6930, r_ui=3.5, est=3.5966637945602002, details={'was_impossible': False}),
#  Prediction(uid=400, iid=39, r_ui=4.0, est=3.7065147726756233, details={'was_impossible': False}),
#  Prediction(uid=23, iid=788, r_ui=2.0, est=3.3365365075777067, details={'was_impossible': False}),
#  Prediction(uid=450, iid=79132, r_ui=4.0, est=4.042996837244495, details={'was_impossible': False}),
#  Prediction(uid=518, iid=902, r_ui=3.0, est=3.441049035168737, details={'was_impossible': False}),
#  Prediction(uid=452, iid=1641, r_ui=4.0, est=3.759006015899591, details={'was_impossible': False}),
#  Prediction(uid=348, iid=111, r_ui=5.0, est=4.120528493780012, details={'was_impossible': False}),
#  Prediction(uid=537, iid=937, r_ui=5.0, est=3.509078241973764, details={'was_impossible': False}),
#  Prediction(uid=452, iid=4855, r_ui=3.0, est=3.375836519045028, details={'was_impossible': False}),
#  Prediction(uid=654, iid=3844, r_ui=4.0, est=4.122943005514376, details={'was_impossible': False}),
#  Prediction(uid=561, iid=2605, r_ui=3.0, est=3.4066372079032803, details={'was_impossible': False}),
#  Prediction(uid=294, iid=8529, r_ui=3.5, est=3.490484246931406, details={'was_impossible': False}),
#  Prediction(uid=406, iid=4993, r_ui=5.0, est=4.65201542738325, details={'was_impossible': False}),
#  Prediction(uid=294, iid=6333, r_ui=4.5, est=3.7581351488939925, details={'was_impossible': False}),
#  Prediction(uid=620, iid=99149, r_ui=4.0, est=2.6702140568603316, details={'was_impossible': False}),
#  Prediction(uid=623, iid=2692, r_ui=4.5, est=4.804030217427168, details={'was_impossible': False}),
#  Prediction(uid=43, iid=3409, r_ui=4.0, est=2.410260529683101, details={'was_impossible': False}),
#  Prediction(uid=547, iid=6868, r_ui=3.5, est=3.220254337079375, details={'was_impossible': False}),
#  Prediction(uid=457, iid=410, r_ui=1.5, est=2.0771168694994344, details={'was_impossible': False}),
#  Prediction(uid=466, iid=899, r_ui=5.0, est=4.271643481456649, details={'was_impossible': False}),
#  Prediction(uid=324, iid=1200, r_ui=3.0, est=3.986892790821224, details={'was_impossible': False}),
#  Prediction(uid=607, iid=2139, r_ui=3.5, est=3.6526390652783576, details={'was_impossible': False}),
#  Prediction(uid=353, iid=2628, r_ui=2.0, est=1.9015452855582637, details={'was_impossible': False}),
#  Prediction(uid=294, iid=168, r_ui=3.0, est=3.278964491937936, details={'was_impossible': False}),
#  Prediction(uid=468, iid=80862, r_ui=3.0, est=3.003630156543519, details={'was_impossible': False}),
#  Prediction(uid=423, iid=27397, r_ui=4.0, est=3.3931859916016456, details={'was_impossible': False}),
#  Prediction(uid=294, iid=7122, r_ui=3.5, est=3.686778610709951, details={'was_impossible': False}),
#  Prediction(uid=393, iid=1527, r_ui=3.5, est=3.2838147930071524, details={'was_impossible': False}),
#  Prediction(uid=593, iid=288, r_ui=5.0, est=3.8143863309743598, details={'was_impossible': False}),
#  Prediction(uid=595, iid=1081, r_ui=4.0, est=3.9207195878040526, details={'was_impossible': False}),
#  Prediction(uid=608, iid=70, r_ui=3.0, est=3.3543477849249625, details={'was_impossible': False}),
#  Prediction(uid=67, iid=279, r_ui=5.0, est=3.3110349799455125, details={'was_impossible': False}),
#  Prediction(uid=220, iid=3257, r_ui=3.0, est=3.097889399824302, details={'was_impossible': False}),
#  Prediction(uid=466, iid=1394, r_ui=4.0, est=3.920940399614016, details={'was_impossible': False}),
#  Prediction(uid=545, iid=1193, r_ui=5.0, est=4.113114689667436, details={'was_impossible': False}),
#  Prediction(uid=177, iid=1784, r_ui=4.0, est=4.147728093325567, details={'was_impossible': False}),
#  Prediction(uid=367, iid=5095, r_ui=4.0, est=3.257039428620389, details={'was_impossible': False}),
#  Prediction(uid=505, iid=2352, r_ui=3.5, est=3.2695631797240283, details={'was_impossible': False}),
#  Prediction(uid=598, iid=2542, r_ui=4.0, est=4.031420642888424, details={'was_impossible': False}),
#  Prediction(uid=534, iid=3269, r_ui=4.0, est=3.0630884315139277, details={'was_impossible': False}),
#  Prediction(uid=48, iid=62956, r_ui=3.5, est=3.5347025048988234, details={'was_impossible': False}),
#  Prediction(uid=67, iid=107, r_ui=3.0, est=3.527983464066596, details={'was_impossible': False}),
#  Prediction(uid=380, iid=3175, r_ui=3.0, est=3.374438154820168, details={'was_impossible': False}),
#  Prediction(uid=15, iid=70697, r_ui=2.5, est=2.5545157385870825, details={'was_impossible': False}),
#  Prediction(uid=654, iid=1393, r_ui=4.5, est=4.2467496856691165, details={'was_impossible': False}),
#  Prediction(uid=77, iid=3471, r_ui=4.0, est=3.7717566293493077, details={'was_impossible': False}),
#  Prediction(uid=468, iid=1219, r_ui=4.5, est=3.5823640597637536, details={'was_impossible': False}),
#  Prediction(uid=306, iid=4034, r_ui=5.0, est=3.5587820469962748, details={'was_impossible': False}),
#  Prediction(uid=383, iid=562, r_ui=4.0, est=3.2898272013032814, details={'was_impossible': False}),
#  Prediction(uid=312, iid=1544, r_ui=3.0, est=2.5313986652833553, details={'was_impossible': False}),
#  Prediction(uid=213, iid=122892, r_ui=4.0, est=3.044282649634735, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1186, r_ui=2.0, est=4.176468280462715, details={'was_impossible': False}),
#  Prediction(uid=534, iid=3557, r_ui=3.0, est=3.8736529013509053, details={'was_impossible': False}),
#  Prediction(uid=93, iid=914, r_ui=3.5, est=3.857118663700189, details={'was_impossible': False}),
#  Prediction(uid=56, iid=89759, r_ui=4.0, est=3.6317508597236663, details={'was_impossible': False}),
#  Prediction(uid=306, iid=2144, r_ui=4.0, est=3.5411748823319464, details={'was_impossible': False}),
#  Prediction(uid=441, iid=6874, r_ui=4.0, est=3.5248960868017343, details={'was_impossible': False}),
#  Prediction(uid=431, iid=357, r_ui=2.0, est=3.684350348540362, details={'was_impossible': False}),
#  Prediction(uid=212, iid=4103, r_ui=3.5, est=3.776241106419398, details={'was_impossible': False}),
#  Prediction(uid=468, iid=908, r_ui=4.0, est=3.5774030746697547, details={'was_impossible': False}),
#  Prediction(uid=30, iid=3101, r_ui=5.0, est=3.8418770825340616, details={'was_impossible': False}),
#  Prediction(uid=509, iid=2425, r_ui=4.0, est=3.1962945826291422, details={'was_impossible': False}),
#  Prediction(uid=81, iid=3637, r_ui=4.0, est=3.722409480784273, details={'was_impossible': False}),
#  Prediction(uid=232, iid=2202, r_ui=4.0, est=4.104059208011571, details={'was_impossible': False}),
#  Prediction(uid=547, iid=1883, r_ui=3.0, est=3.154926406786361, details={'was_impossible': False}),
#  Prediction(uid=461, iid=1617, r_ui=5.0, est=3.812044539388946, details={'was_impossible': False}),
#  Prediction(uid=555, iid=590, r_ui=3.0, est=3.2753346288445493, details={'was_impossible': False}),
#  Prediction(uid=468, iid=5449, r_ui=0.5, est=2.4065740820410824, details={'was_impossible': False}),
#  Prediction(uid=175, iid=4447, r_ui=4.0, est=3.433190417897588, details={'was_impossible': False}),
#  Prediction(uid=627, iid=39446, r_ui=4.0, est=2.810513662947951, details={'was_impossible': False}),
#  Prediction(uid=624, iid=3698, r_ui=2.0, est=3.051272174958366, details={'was_impossible': False}),
#  Prediction(uid=461, iid=2485, r_ui=2.5, est=2.1651637978497646, details={'was_impossible': False}),
#  Prediction(uid=361, iid=1210, r_ui=5.0, est=4.201658943183538, details={'was_impossible': False}),
#  Prediction(uid=361, iid=780, r_ui=5.0, est=3.863785890697661, details={'was_impossible': False}),
#  Prediction(uid=547, iid=33917, r_ui=4.0, est=3.2885895440236426, details={'was_impossible': False}),
#  Prediction(uid=615, iid=2329, r_ui=4.0, est=4.195687811532751, details={'was_impossible': False}),
#  Prediction(uid=94, iid=1246, r_ui=3.0, est=3.4750516588898726, details={'was_impossible': False}),
#  Prediction(uid=177, iid=50, r_ui=5.0, est=4.8399637669878715, details={'was_impossible': False}),
#  Prediction(uid=247, iid=2141, r_ui=4.0, est=3.7564258321123223, details={'was_impossible': False}),
#  Prediction(uid=461, iid=381, r_ui=1.0, est=2.792824573015368, details={'was_impossible': False}),
#  Prediction(uid=38, iid=55118, r_ui=4.5, est=4.0053856602138245, details={'was_impossible': False}),
#  Prediction(uid=199, iid=68319, r_ui=3.5, est=3.167650266197542, details={'was_impossible': False}),
#  Prediction(uid=547, iid=63629, r_ui=4.0, est=3.2885895440236426, details={'was_impossible': False}),
#  Prediction(uid=550, iid=2762, r_ui=5.0, est=4.478234819168985, details={'was_impossible': False}),
#  Prediction(uid=294, iid=25971, r_ui=3.5, est=3.4875154354799656, details={'was_impossible': False}),
#  Prediction(uid=213, iid=2581, r_ui=2.5, est=2.750079473697707, details={'was_impossible': False}),
#  Prediction(uid=481, iid=71535, r_ui=1.0, est=3.9242734506234433, details={'was_impossible': False}),
#  Prediction(uid=324, iid=551, r_ui=4.0, est=3.6242969791563957, details={'was_impossible': False}),
#  Prediction(uid=430, iid=1197, r_ui=4.5, est=4.720528860299839, details={'was_impossible': False}),
#  Prediction(uid=529, iid=7979, r_ui=3.5, est=3.432293641285198, details={'was_impossible': False}),
#  Prediction(uid=119, iid=1606, r_ui=2.0, est=2.780373473403119, details={'was_impossible': False}),
#  Prediction(uid=189, iid=2428, r_ui=3.0, est=2.2300180303383303, details={'was_impossible': False}),
#  Prediction(uid=30, iid=5506, r_ui=4.0, est=3.5347708106313034, details={'was_impossible': False}),
#  Prediction(uid=547, iid=34437, r_ui=3.0, est=3.4553014236737765, details={'was_impossible': False}),
#  Prediction(uid=562, iid=6365, r_ui=4.0, est=3.7834316490927717, details={'was_impossible': False}),
#  Prediction(uid=602, iid=272, r_ui=4.0, est=3.870669762889057, details={'was_impossible': False}),
#  Prediction(uid=564, iid=126, r_ui=1.0, est=3.2987330881067045, details={'was_impossible': False}),
#  Prediction(uid=580, iid=52973, r_ui=3.5, est=3.254606439757011, details={'was_impossible': False}),
#  Prediction(uid=463, iid=1674, r_ui=4.0, est=3.764582757080293, details={'was_impossible': False}),
#  Prediction(uid=161, iid=350, r_ui=5.0, est=3.396251583801896, details={'was_impossible': False}),
#  Prediction(uid=518, iid=248, r_ui=3.0, est=2.960367417011912, details={'was_impossible': False}),
#  Prediction(uid=519, iid=608, r_ui=4.0, est=4.647060796918403, details={'was_impossible': False}),
#  Prediction(uid=199, iid=54771, r_ui=3.0, est=3.6660748400422256, details={'was_impossible': False}),
#  Prediction(uid=620, iid=7153, r_ui=1.0, est=3.7108283945138694, details={'was_impossible': False}),
#  Prediction(uid=430, iid=4306, r_ui=4.0, est=4.070164208871007, details={'was_impossible': False}),
#  Prediction(uid=493, iid=3244, r_ui=3.0, est=3.322127502033684, details={'was_impossible': False}),
#  Prediction(uid=239, iid=4066, r_ui=4.0, est=4.0330196717965, details={'was_impossible': False}),
#  Prediction(uid=385, iid=442, r_ui=3.0, est=2.9957261981182817, details={'was_impossible': False}),
#  Prediction(uid=353, iid=72, r_ui=2.5, est=2.335259218095089, details={'was_impossible': False}),
#  Prediction(uid=544, iid=61323, r_ui=5.0, est=4.463769828870315, details={'was_impossible': False}),
#  Prediction(uid=119, iid=1944, r_ui=4.0, est=3.7569029015992146, details={'was_impossible': False}),
#  Prediction(uid=468, iid=8264, r_ui=4.0, est=3.35609868855948, details={'was_impossible': False}),
#  Prediction(uid=232, iid=50, r_ui=5.0, est=4.647072619204986, details={'was_impossible': False}),
#  Prediction(uid=478, iid=8368, r_ui=4.5, est=4.154598319785714, details={'was_impossible': False}),
#  Prediction(uid=119, iid=3052, r_ui=5.0, est=3.567237111651607, details={'was_impossible': False}),
#  Prediction(uid=376, iid=4223, r_ui=4.0, est=3.8921979350881206, details={'was_impossible': False}),
#  Prediction(uid=667, iid=356, r_ui=4.0, est=4.1844498889331705, details={'was_impossible': False}),
#  Prediction(uid=120, iid=4306, r_ui=2.5, est=3.864644156180467, details={'was_impossible': False}),
#  Prediction(uid=254, iid=72, r_ui=4.0, est=3.540247285537746, details={'was_impossible': False}),
#  Prediction(uid=110, iid=252, r_ui=4.0, est=4.012823479040923, details={'was_impossible': False}),
#  Prediction(uid=19, iid=318, r_ui=4.0, est=4.096374704636288, details={'was_impossible': False}),
#  Prediction(uid=350, iid=4993, r_ui=5.0, est=4.527433250909353, details={'was_impossible': False}),
#  Prediction(uid=20, iid=8493, r_ui=3.5, est=3.448725801013035, details={'was_impossible': False}),
#  Prediction(uid=15, iid=3262, r_ui=1.0, est=2.587481666641956, details={'was_impossible': False}),
#  Prediction(uid=297, iid=2826, r_ui=3.0, est=2.644772403158129, details={'was_impossible': False}),
#  Prediction(uid=544, iid=5502, r_ui=4.5, est=3.790455440381025, details={'was_impossible': False}),
#  Prediction(uid=30, iid=2193, r_ui=3.0, est=3.4096990932680935, details={'was_impossible': False}),
#  Prediction(uid=34, iid=1092, r_ui=4.0, est=3.784049823408669, details={'was_impossible': False}),
#  Prediction(uid=468, iid=3999, r_ui=1.5, est=2.294205698538165, details={'was_impossible': False}),
#  Prediction(uid=428, iid=72998, r_ui=2.5, est=3.5192811272611655, details={'was_impossible': False}),
#  Prediction(uid=577, iid=736, r_ui=3.0, est=4.1209260713455995, details={'was_impossible': False}),
#  Prediction(uid=596, iid=539, r_ui=3.0, est=3.440272868716601, details={'was_impossible': False}),
#  Prediction(uid=561, iid=1274, r_ui=3.5, est=3.5849382389879825, details={'was_impossible': False}),
#  Prediction(uid=397, iid=413, r_ui=2.0, est=2.612249867176567, details={'was_impossible': False}),
#  Prediction(uid=509, iid=3448, r_ui=4.0, est=3.356496102971927, details={'was_impossible': False}),
#  Prediction(uid=514, iid=606, r_ui=3.0, est=2.993903253318416, details={'was_impossible': False}),
#  Prediction(uid=665, iid=216, r_ui=4.0, est=3.2858776506034166, details={'was_impossible': False}),
#  Prediction(uid=564, iid=1185, r_ui=3.0, est=3.3155186488678385, details={'was_impossible': False}),
#  Prediction(uid=67, iid=337, r_ui=4.0, est=3.9564190341475096, details={'was_impossible': False}),
#  Prediction(uid=529, iid=1179, r_ui=5.0, est=3.5749043337740747, details={'was_impossible': False}),
#  Prediction(uid=509, iid=1562, r_ui=2.0, est=2.0230033238810763, details={'was_impossible': False}),
#  Prediction(uid=624, iid=93242, r_ui=1.5, est=2.916861541649824, details={'was_impossible': False}),
#  Prediction(uid=665, iid=3051, r_ui=3.0, est=2.8600071030652328, details={'was_impossible': False}),
#  Prediction(uid=575, iid=3654, r_ui=3.0, est=3.2627951865707723, details={'was_impossible': False}),
#  Prediction(uid=624, iid=39183, r_ui=3.0, est=2.9444142009040988, details={'was_impossible': False}),
#  Prediction(uid=660, iid=108932, r_ui=4.5, est=4.038598350907109, details={'was_impossible': False}),
#  Prediction(uid=253, iid=3255, r_ui=4.5, est=3.5755886499326226, details={'was_impossible': False}),
#  Prediction(uid=547, iid=2804, r_ui=3.0, est=3.911488300966773, details={'was_impossible': False}),
#  Prediction(uid=235, iid=5679, r_ui=4.5, est=4.097890836220572, details={'was_impossible': False}),
#  Prediction(uid=371, iid=356, r_ui=5.0, est=3.9738488827799845, details={'was_impossible': False}),
#  Prediction(uid=388, iid=1213, r_ui=5.0, est=4.698518279885517, details={'was_impossible': False}),
#  Prediction(uid=15, iid=5266, r_ui=1.0, est=2.179085005593395, details={'was_impossible': False}),
#  Prediction(uid=303, iid=367, r_ui=2.0, est=2.9543531651302555, details={'was_impossible': False}),
#  Prediction(uid=420, iid=355, r_ui=3.0, est=2.2495787708394035, details={'was_impossible': False}),
#  Prediction(uid=30, iid=2750, r_ui=4.0, est=3.6948946823030058, details={'was_impossible': False}),
#  Prediction(uid=463, iid=1370, r_ui=2.0, est=3.0473927690294396, details={'was_impossible': False}),
#  Prediction(uid=48, iid=55280, r_ui=4.0, est=3.638595659207305, details={'was_impossible': False}),
#  Prediction(uid=653, iid=2762, r_ui=5.0, est=4.24658969927739, details={'was_impossible': False}),
#  Prediction(uid=75, iid=904, r_ui=4.0, est=3.6485020332686737, details={'was_impossible': False}),
#  Prediction(uid=130, iid=1968, r_ui=4.5, est=3.7304467462440787, details={'was_impossible': False}),
#  Prediction(uid=33, iid=5669, r_ui=4.0, est=3.483658113118896, details={'was_impossible': False}),
#  Prediction(uid=38, iid=365, r_ui=4.5, est=3.733502709088899, details={'was_impossible': False}),
#  Prediction(uid=292, iid=5377, r_ui=4.0, est=4.297304232609086, details={'was_impossible': False}),
#  Prediction(uid=214, iid=2985, r_ui=4.0, est=3.954849088900858, details={'was_impossible': False}),
#  Prediction(uid=518, iid=2333, r_ui=4.0, est=3.75996637797365, details={'was_impossible': False}),
#  Prediction(uid=345, iid=1372, r_ui=2.0, est=3.1848947533318386, details={'was_impossible': False}),
#  Prediction(uid=166, iid=653, r_ui=3.0, est=3.001417606221936, details={'was_impossible': False}),
#  Prediction(uid=350, iid=2794, r_ui=3.0, est=3.2623092967816207, details={'was_impossible': False}),
#  Prediction(uid=646, iid=1688, r_ui=3.0, est=4.169700263777248, details={'was_impossible': False}),
#  Prediction(uid=460, iid=1394, r_ui=4.5, est=4.0757678146383105, details={'was_impossible': False}),
#  Prediction(uid=457, iid=5900, r_ui=1.5, est=1.822331301565896, details={'was_impossible': False}),
#  Prediction(uid=609, iid=4784, r_ui=1.0, est=1.6320011006261923, details={'was_impossible': False}),
#  Prediction(uid=358, iid=370, r_ui=1.0, est=2.972486540815659, details={'was_impossible': False}),
#  Prediction(uid=414, iid=2962, r_ui=3.0, est=2.7840482416753582, details={'was_impossible': False}),
#  Prediction(uid=205, iid=67255, r_ui=4.5, est=3.2713404081781094, details={'was_impossible': False}),
#  Prediction(uid=655, iid=7153, r_ui=5.0, est=4.510251925852738, details={'was_impossible': False}),
#  Prediction(uid=294, iid=2989, r_ui=2.5, est=3.8530358314825417, details={'was_impossible': False}),
#  Prediction(uid=22, iid=4383, r_ui=3.5, est=3.177334199877179, details={'was_impossible': False}),
#  Prediction(uid=346, iid=112, r_ui=4.0, est=3.21826688902377, details={'was_impossible': False}),
#  Prediction(uid=160, iid=3362, r_ui=5.0, est=4.4672165294332915, details={'was_impossible': False}),
#  Prediction(uid=211, iid=1225, r_ui=5.0, est=4.727506565145846, details={'was_impossible': False}),
#  Prediction(uid=654, iid=236, r_ui=4.0, est=3.628695083936792, details={'was_impossible': False}),
#  Prediction(uid=232, iid=923, r_ui=5.0, est=4.868301906599389, details={'was_impossible': False}),
#  Prediction(uid=212, iid=5810, r_ui=3.0, est=3.15246578097651, details={'was_impossible': False}),
#  Prediction(uid=461, iid=8464, r_ui=3.5, est=3.4467998944248004, details={'was_impossible': False}),
#  Prediction(uid=125, iid=1234, r_ui=4.0, est=4.29819567660967, details={'was_impossible': False}),
#  Prediction(uid=30, iid=3489, r_ui=4.0, est=3.3252010039256303, details={'was_impossible': False}),
#  Prediction(uid=102, iid=3735, r_ui=5.0, est=4.330539611487637, details={'was_impossible': False}),
#  Prediction(uid=348, iid=337, r_ui=5.0, est=3.5036386297403475, details={'was_impossible': False}),
#  Prediction(uid=288, iid=31, r_ui=3.0, est=3.188761713095731, details={'was_impossible': False}),
#  Prediction(uid=42, iid=33794, r_ui=3.5, est=3.960232880012071, details={'was_impossible': False}),
#  Prediction(uid=130, iid=260, r_ui=4.5, est=4.552319616149748, details={'was_impossible': False}),
#  Prediction(uid=468, iid=48301, r_ui=4.0, est=2.8434337279749995, details={'was_impossible': False}),
#  Prediction(uid=17, iid=7068, r_ui=4.5, est=3.2469825683431024, details={'was_impossible': False}),
#  Prediction(uid=623, iid=48516, r_ui=4.5, est=4.64032370955113, details={'was_impossible': False}),
#  Prediction(uid=665, iid=516, r_ui=2.0, est=3.0455676027431315, details={'was_impossible': False}),
#  Prediction(uid=461, iid=934, r_ui=2.5, est=2.8942470012177144, details={'was_impossible': False}),
#  Prediction(uid=551, iid=273, r_ui=4.0, est=3.234268760025058, details={'was_impossible': False}),
#  Prediction(uid=564, iid=2378, r_ui=4.0, est=2.9281109961964993, details={'was_impossible': False}),
#  Prediction(uid=213, iid=122886, r_ui=4.0, est=2.675797955288269, details={'was_impossible': False}),
#  Prediction(uid=648, iid=2324, r_ui=4.5, est=4.164421776593021, details={'was_impossible': False}),
#  Prediction(uid=564, iid=3809, r_ui=4.0, est=3.417380340538335, details={'was_impossible': False}),
#  Prediction(uid=574, iid=1918, r_ui=4.0, est=2.80340921339863, details={'was_impossible': False}),
#  Prediction(uid=660, iid=69844, r_ui=4.5, est=4.56535557688583, details={'was_impossible': False}),
#  Prediction(uid=475, iid=69526, r_ui=0.5, est=1.7796124001200408, details={'was_impossible': False}),
#  Prediction(uid=550, iid=1610, r_ui=4.0, est=4.202555192935295, details={'was_impossible': False}),
#  Prediction(uid=15, iid=1248, r_ui=3.0, est=3.478212236775597, details={'was_impossible': False}),
#  Prediction(uid=236, iid=47, r_ui=2.5, est=4.3242313059904145, details={'was_impossible': False}),
#  Prediction(uid=362, iid=8327, r_ui=4.5, est=3.5143392718178585, details={'was_impossible': False}),
#  Prediction(uid=214, iid=1997, r_ui=5.0, est=3.9912427928833343, details={'was_impossible': False}),
#  Prediction(uid=602, iid=2, r_ui=4.0, est=3.2374099060250003, details={'was_impossible': False}),
#  Prediction(uid=584, iid=46972, r_ui=2.5, est=3.4986555971094, details={'was_impossible': False}),
#  Prediction(uid=394, iid=27351, r_ui=1.0, est=2.620605012070289, details={'was_impossible': False}),
#  Prediction(uid=547, iid=5017, r_ui=5.0, est=3.4655236567930188, details={'was_impossible': False}),
#  Prediction(uid=547, iid=7614, r_ui=4.0, est=3.6983237802684683, details={'was_impossible': False}),
#  Prediction(uid=63, iid=2268, r_ui=4.0, est=3.7990793274684096, details={'was_impossible': False}),
#  Prediction(uid=402, iid=73017, r_ui=4.0, est=3.8156453120936265, details={'was_impossible': False}),
#  Prediction(uid=91, iid=4718, r_ui=4.0, est=3.7576091483622904, details={'was_impossible': False}),
#  Prediction(uid=235, iid=1380, r_ui=4.0, est=4.210160706717952, details={'was_impossible': False}),
#  Prediction(uid=408, iid=47, r_ui=5.0, est=4.358531431209783, details={'was_impossible': False}),
#  Prediction(uid=550, iid=2334, r_ui=3.0, est=3.4993141185574888, details={'was_impossible': False}),
#  Prediction(uid=659, iid=422, r_ui=3.0, est=3.161294287271088, details={'was_impossible': False}),
#  Prediction(uid=166, iid=4262, r_ui=4.0, est=3.6303102314367517, details={'was_impossible': False}),
#  Prediction(uid=30, iid=1584, r_ui=5.0, est=4.008287422017057, details={'was_impossible': False}),
#  Prediction(uid=412, iid=3743, r_ui=2.0, est=2.906780013740093, details={'was_impossible': False}),
#  Prediction(uid=475, iid=5445, r_ui=3.0, est=2.8951195883305063, details={'was_impossible': False}),
#  Prediction(uid=38, iid=33794, r_ui=4.0, est=4.430809650131477, details={'was_impossible': False}),
#  Prediction(uid=15, iid=2428, r_ui=1.0, est=1.6807221645059103, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3169, r_ui=4.0, est=4.003001243947006, details={'was_impossible': False}),
#  Prediction(uid=306, iid=1292, r_ui=4.0, est=3.71502326142326, details={'was_impossible': False}),
#  Prediction(uid=8, iid=2804, r_ui=3.5, est=4.037371728447111, details={'was_impossible': False}),
#  Prediction(uid=564, iid=1924, r_ui=3.0, est=4.435287435425072, details={'was_impossible': False}),
#  Prediction(uid=428, iid=27879, r_ui=3.0, est=3.52787920031761, details={'was_impossible': False}),
#  Prediction(uid=608, iid=696, r_ui=1.0, est=3.9096508588125096, details={'was_impossible': False}),
#  Prediction(uid=344, iid=1347, r_ui=2.0, est=3.7933440901581323, details={'was_impossible': False}),
#  Prediction(uid=59, iid=3578, r_ui=4.0, est=3.1769851813899144, details={'was_impossible': False}),
#  Prediction(uid=558, iid=2944, r_ui=4.0, est=4.304495730462336, details={'was_impossible': False}),
#  Prediction(uid=431, iid=1210, r_ui=4.5, est=4.818452753194524, details={'was_impossible': False}),
#  Prediction(uid=199, iid=1165, r_ui=1.5, est=3.531915734186773, details={'was_impossible': False}),
#  Prediction(uid=137, iid=1210, r_ui=5.0, est=4.008523194477606, details={'was_impossible': False}),
#  Prediction(uid=73, iid=1792, r_ui=2.5, est=3.1524528245197816, details={'was_impossible': False}),
# ...
#  Prediction(uid=23, iid=2183, r_ui=3.5, est=3.651161354079168, details={'was_impossible': False}),
#  Prediction(uid=452, iid=3044, r_ui=3.0, est=3.686818193927223, details={'was_impossible': False}),
#  Prediction(uid=461, iid=5049, r_ui=3.5, est=2.7560139402281676, details={'was_impossible': False}),
#  Prediction(uid=295, iid=6708, r_ui=5.0, est=4.11350761731816, details={'was_impossible': False}),
#  Prediction(uid=213, iid=94780, r_ui=4.0, est=3.1909604471427304, details={'was_impossible': False}),
#  Prediction(uid=550, iid=338, r_ui=4.0, est=2.9501490054577997, details={'was_impossible': False}),
#  Prediction(uid=550, iid=2252, r_ui=4.0, est=3.374530393389811, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1954, r_ui=3.0, est=3.80586681876534, details={'was_impossible': False}),
#  Prediction(uid=577, iid=6333, r_ui=4.5, est=4.253780347883465, details={'was_impossible': False}),
#  Prediction(uid=346, iid=1374, r_ui=4.0, est=4.00070397807385, details={'was_impossible': False}),
#  Prediction(uid=660, iid=79357, r_ui=4.0, est=3.928753054965247, details={'was_impossible': False}),
#  Prediction(uid=117, iid=85881, r_ui=4.0, est=3.5299625319599905, details={'was_impossible': False}),
#  Prediction(uid=224, iid=314, r_ui=4.0, est=4.082909510453629, details={'was_impossible': False}),
#  Prediction(uid=73, iid=2974, r_ui=1.0, est=3.0170186839966533, details={'was_impossible': False}),
#  Prediction(uid=15, iid=7147, r_ui=1.5, est=3.1449330935329165, details={'was_impossible': False}),
#  Prediction(uid=19, iid=1284, r_ui=4.0, est=3.8732265718757457, details={'was_impossible': False}),
#  Prediction(uid=232, iid=1270, r_ui=5.0, est=4.521007830139872, details={'was_impossible': False}),
#  Prediction(uid=542, iid=858, r_ui=5.0, est=4.264238434269678, details={'was_impossible': False}),
#  Prediction(uid=61, iid=60069, r_ui=5.0, est=3.4864667220063357, details={'was_impossible': False}),
#  Prediction(uid=124, iid=6323, r_ui=3.0, est=3.6178712700783593, details={'was_impossible': False}),
#  Prediction(uid=318, iid=704, r_ui=5.0, est=2.8465573106286355, details={'was_impossible': False}),
#  Prediction(uid=292, iid=587, r_ui=4.0, est=3.674238984625371, details={'was_impossible': False}),
#  Prediction(uid=394, iid=1148, r_ui=2.0, est=3.054771340545002, details={'was_impossible': False}),
#  Prediction(uid=598, iid=110, r_ui=4.0, est=3.8516031596016367, details={'was_impossible': False}),
#  Prediction(uid=585, iid=905, r_ui=5.0, est=4.549819550535552, details={'was_impossible': False}),
#  Prediction(uid=254, iid=538, r_ui=5.0, est=3.6730965167847933, details={'was_impossible': False}),
#  Prediction(uid=447, iid=413, r_ui=1.0, est=2.4902001786333963, details={'was_impossible': False}),
#  Prediction(uid=110, iid=257, r_ui=4.0, est=4.1441330384023995, details={'was_impossible': False}),
#  Prediction(uid=111, iid=5829, r_ui=3.0, est=3.3925825797714135, details={'was_impossible': False}),
#  Prediction(uid=649, iid=434, r_ui=4.0, est=3.137026271720297, details={'was_impossible': False}),
#  Prediction(uid=594, iid=2726, r_ui=4.0, est=4.006214153095137, details={'was_impossible': False}),
#  Prediction(uid=73, iid=784, r_ui=1.0, est=2.4940212629239658, details={'was_impossible': False}),
#  Prediction(uid=353, iid=36529, r_ui=3.5, est=2.851358435820727, details={'was_impossible': False}),
#  Prediction(uid=388, iid=2376, r_ui=2.0, est=3.206118390141014, details={'was_impossible': False}),
#  Prediction(uid=458, iid=2273, r_ui=3.0, est=3.611221074048949, details={'was_impossible': False}),
#  Prediction(uid=586, iid=1962, r_ui=3.0, est=3.464432199078803, details={'was_impossible': False}),
#  Prediction(uid=607, iid=2605, r_ui=2.5, est=3.4689951564203385, details={'was_impossible': False}),
#  Prediction(uid=118, iid=2391, r_ui=5.0, est=4.166239591089862, details={'was_impossible': False}),
#  Prediction(uid=30, iid=6436, r_ui=5.0, est=3.520477180462948, details={'was_impossible': False}),
#  Prediction(uid=304, iid=45950, r_ui=4.0, est=3.648241861628507, details={'was_impossible': False}),
#  Prediction(uid=244, iid=1200, r_ui=4.0, est=3.522478032605827, details={'was_impossible': False}),
#  Prediction(uid=250, iid=6016, r_ui=4.0, est=4.768930084826129, details={'was_impossible': False}),
#  Prediction(uid=73, iid=79879, r_ui=2.5, est=3.704706040890201, details={'was_impossible': False}),
#  Prediction(uid=461, iid=5349, r_ui=4.0, est=3.0444710396185153, details={'was_impossible': False}),
#  Prediction(uid=518, iid=1606, r_ui=3.0, est=3.710282737194501, details={'was_impossible': False}),
#  Prediction(uid=647, iid=541, r_ui=5.0, est=4.402823894252656, details={'was_impossible': False}),
#  Prediction(uid=518, iid=2097, r_ui=5.0, est=3.294120064055182, details={'was_impossible': False}),
#  Prediction(uid=165, iid=5501, r_ui=3.0, est=2.8785645360938577, details={'was_impossible': False}),
#  Prediction(uid=15, iid=44665, r_ui=1.0, est=3.3542892017964574, details={'was_impossible': False}),
#  Prediction(uid=516, iid=203, r_ui=4.0, est=3.470632872335271, details={'was_impossible': False}),
#  Prediction(uid=388, iid=357, r_ui=3.0, est=4.079537185658209, details={'was_impossible': False}),
#  Prediction(uid=529, iid=39183, r_ui=4.5, est=3.3275453149924314, details={'was_impossible': False}),
#  Prediction(uid=529, iid=750, r_ui=4.5, est=4.116201964808346, details={'was_impossible': False}),
#  Prediction(uid=594, iid=2706, r_ui=3.0, est=3.7243209163650133, details={'was_impossible': False}),
#  Prediction(uid=125, iid=8981, r_ui=4.0, est=4.216381964370716, details={'was_impossible': False}),
#  Prediction(uid=452, iid=2352, r_ui=4.0, est=3.5105249211113554, details={'was_impossible': False}),
#  Prediction(uid=575, iid=1077, r_ui=4.0, est=4.084685103477648, details={'was_impossible': False}),
#  Prediction(uid=509, iid=3510, r_ui=3.0, est=2.986623091716202, details={'was_impossible': False}),
#  Prediction(uid=236, iid=7013, r_ui=5.0, est=3.9503947965792414, details={'was_impossible': False}),
#  Prediction(uid=473, iid=101142, r_ui=4.0, est=4.052869986331382, details={'was_impossible': False}),
#  Prediction(uid=119, iid=3527, r_ui=4.0, est=3.5396534031434648, details={'was_impossible': False}),
#  Prediction(uid=509, iid=508, r_ui=3.0, est=3.2667298933598983, details={'was_impossible': False}),
#  Prediction(uid=624, iid=5752, r_ui=3.0, est=3.1659661796857588, details={'was_impossible': False}),
#  Prediction(uid=105, iid=1246, r_ui=1.5, est=3.7126686912147346, details={'was_impossible': False}),
#  Prediction(uid=288, iid=161, r_ui=3.0, est=4.128693476675225, details={'was_impossible': False}),
#  Prediction(uid=232, iid=126, r_ui=3.0, est=3.4046579621010946, details={'was_impossible': False}),
#  Prediction(uid=182, iid=594, r_ui=5.0, est=4.252882708759193, details={'was_impossible': False}),
#  Prediction(uid=481, iid=81591, r_ui=4.0, est=4.1515325315618865, details={'was_impossible': False}),
#  Prediction(uid=547, iid=51540, r_ui=4.0, est=4.041984345648766, details={'was_impossible': False}),
#  Prediction(uid=481, iid=138696, r_ui=5.0, est=3.9197317908307143, details={'was_impossible': False}),
#  Prediction(uid=99, iid=2529, r_ui=1.0, est=3.505789645631723, details={'was_impossible': False}),
#  Prediction(uid=524, iid=54997, r_ui=4.5, est=4.092114185330803, details={'was_impossible': False}),
#  Prediction(uid=466, iid=2352, r_ui=3.0, est=3.7319645484990605, details={'was_impossible': False}),
#  Prediction(uid=73, iid=90376, r_ui=3.5, est=3.2574764608429083, details={'was_impossible': False}),
#  Prediction(uid=381, iid=914, r_ui=4.0, est=3.8563196053074797, details={'was_impossible': False}),
#  Prediction(uid=596, iid=1092, r_ui=3.5, est=3.354645269491284, details={'was_impossible': False}),
#  Prediction(uid=2, iid=537, r_ui=4.0, est=2.963823684894634, details={'was_impossible': False}),
#  Prediction(uid=376, iid=4238, r_ui=5.0, est=3.276759758347562, details={'was_impossible': False}),
#  Prediction(uid=386, iid=1967, r_ui=3.0, est=2.8843768660393043, details={'was_impossible': False}),
#  Prediction(uid=547, iid=87306, r_ui=4.0, est=3.3971287543533015, details={'was_impossible': False}),
#  Prediction(uid=402, iid=4446, r_ui=3.0, est=3.433672806173887, details={'was_impossible': False}),
#  Prediction(uid=529, iid=1080, r_ui=4.0, est=4.076000588479223, details={'was_impossible': False}),
#  Prediction(uid=587, iid=5225, r_ui=4.0, est=4.5504995356616185, details={'was_impossible': False}),
#  Prediction(uid=525, iid=1552, r_ui=5.0, est=3.0362011060294356, details={'was_impossible': False}),
#  Prediction(uid=564, iid=3244, r_ui=5.0, est=3.637716813016473, details={'was_impossible': False}),
#  Prediction(uid=487, iid=433, r_ui=3.0, est=3.8616853255386205, details={'was_impossible': False}),
#  Prediction(uid=383, iid=784, r_ui=2.0, est=2.314622864850877, details={'was_impossible': False}),
#  Prediction(uid=481, iid=5878, r_ui=5.0, est=4.06415152735847, details={'was_impossible': False}),
#  Prediction(uid=607, iid=316, r_ui=3.5, est=3.388412352030117, details={'was_impossible': False}),
#  Prediction(uid=363, iid=47, r_ui=5.0, est=4.158743467813049, details={'was_impossible': False}),
#  Prediction(uid=385, iid=145, r_ui=4.0, est=2.92684890520657, details={'was_impossible': False}),
#  Prediction(uid=564, iid=3167, r_ui=5.0, est=3.9340308717191332, details={'was_impossible': False}),
#  Prediction(uid=73, iid=2033, r_ui=3.5, est=3.0250046056930717, details={'was_impossible': False}),
#  Prediction(uid=615, iid=134853, r_ui=5.0, est=3.629537282460301, details={'was_impossible': False}),
#  Prediction(uid=199, iid=51255, r_ui=4.0, est=3.848611631478377, details={'was_impossible': False}),
#  Prediction(uid=463, iid=222, r_ui=4.0, est=3.6912919678475955, details={'was_impossible': False}),
#  Prediction(uid=61, iid=5693, r_ui=3.5, est=3.0437708319027323, details={'was_impossible': False}),
#  Prediction(uid=19, iid=180, r_ui=3.0, est=2.9727004363413614, details={'was_impossible': False}),
#  Prediction(uid=516, iid=555, r_ui=3.0, est=3.939788741821916, details={'was_impossible': False}),
#  Prediction(uid=126, iid=594, r_ui=3.0, est=3.8867995187295294, details={'was_impossible': False}),
#  Prediction(uid=384, iid=34, r_ui=3.0, est=3.353524071412951, details={'was_impossible': False}),
#  Prediction(uid=427, iid=2607, r_ui=4.0, est=3.8870471111045517, details={'was_impossible': False}),
#  Prediction(uid=268, iid=587, r_ui=3.0, est=3.4424698940411145, details={'was_impossible': False}),
#  Prediction(uid=580, iid=2467, r_ui=4.0, est=3.6094326156775187, details={'was_impossible': False}),
#  Prediction(uid=580, iid=1513, r_ui=3.0, est=2.7776887665452064, details={'was_impossible': False}),
#  Prediction(uid=91, iid=134853, r_ui=4.0, est=4.046967673304925, details={'was_impossible': False}),
#  Prediction(uid=358, iid=2529, r_ui=4.0, est=3.74470102854136, details={'was_impossible': False}),
#  Prediction(uid=558, iid=3147, r_ui=5.0, est=4.652575526647835, details={'was_impossible': False}),
#  Prediction(uid=30, iid=3160, r_ui=5.0, est=4.174259138439307, details={'was_impossible': False}),
#  Prediction(uid=463, iid=587, r_ui=4.0, est=2.9976659737505393, details={'was_impossible': False}),
#  Prediction(uid=607, iid=32587, r_ui=5.0, est=4.001137212558721, details={'was_impossible': False}),
#  Prediction(uid=119, iid=3397, r_ui=4.0, est=3.315898257153007, details={'was_impossible': False}),
#  Prediction(uid=282, iid=4993, r_ui=5.0, est=3.918984107528459, details={'was_impossible': False}),
#  Prediction(uid=316, iid=1291, r_ui=4.0, est=4.106757877357104, details={'was_impossible': False}),
#  Prediction(uid=564, iid=388, r_ui=4.0, est=3.3148323347794912, details={'was_impossible': False}),
#  Prediction(uid=245, iid=1035, r_ui=3.0, est=4.501590802346985, details={'was_impossible': False}),
#  Prediction(uid=15, iid=1171, r_ui=4.0, est=3.4437570357093463, details={'was_impossible': False}),
#  Prediction(uid=463, iid=5620, r_ui=3.0, est=2.7944827678147934, details={'was_impossible': False}),
#  Prediction(uid=480, iid=1717, r_ui=3.5, est=3.5930443619314048, details={'was_impossible': False}),
#  Prediction(uid=105, iid=383, r_ui=3.0, est=3.057973613329021, details={'was_impossible': False}),
#  Prediction(uid=423, iid=4734, r_ui=1.5, est=3.569549214826475, details={'was_impossible': False}),
#  Prediction(uid=150, iid=1704, r_ui=4.0, est=3.9147360526169943, details={'was_impossible': False}),
#  Prediction(uid=213, iid=6996, r_ui=2.5, est=2.633421065718824, details={'was_impossible': False}),
#  Prediction(uid=452, iid=2463, r_ui=3.5, est=3.118326047772031, details={'was_impossible': False}),
#  Prediction(uid=36, iid=372, r_ui=3.0, est=3.2449260728611375, details={'was_impossible': False}),
#  Prediction(uid=518, iid=1894, r_ui=3.0, est=3.465122392631596, details={'was_impossible': False}),
#  Prediction(uid=559, iid=733, r_ui=4.0, est=4.35067715192993, details={'was_impossible': False}),
#  Prediction(uid=387, iid=3146, r_ui=3.0, est=3.017250428318804, details={'was_impossible': False}),
#  Prediction(uid=564, iid=2215, r_ui=4.0, est=3.5396499874829654, details={'was_impossible': False}),
#  Prediction(uid=572, iid=36519, r_ui=3.0, est=3.541047151868938, details={'was_impossible': False}),
#  Prediction(uid=624, iid=1432, r_ui=2.0, est=2.5776874773167604, details={'was_impossible': False}),
#  Prediction(uid=533, iid=2433, r_ui=4.0, est=2.875175264866924, details={'was_impossible': False}),
#  Prediction(uid=537, iid=1422, r_ui=2.0, est=3.390020598153738, details={'was_impossible': False}),
#  Prediction(uid=620, iid=4878, r_ui=2.5, est=3.4446899640918076, details={'was_impossible': False}),
#  Prediction(uid=605, iid=913, r_ui=5.0, est=3.7860099485806598, details={'was_impossible': False}),
#  Prediction(uid=384, iid=3273, r_ui=3.0, est=2.915273959139362, details={'was_impossible': False}),
#  Prediction(uid=534, iid=361, r_ui=3.0, est=3.593054734561527, details={'was_impossible': False}),
#  Prediction(uid=30, iid=2418, r_ui=3.0, est=3.736268054472568, details={'was_impossible': False}),
#  Prediction(uid=213, iid=5816, r_ui=4.0, est=3.0684807645562655, details={'was_impossible': False}),
#  Prediction(uid=471, iid=1210, r_ui=4.5, est=4.222178073369951, details={'was_impossible': False}),
#  Prediction(uid=496, iid=440, r_ui=4.0, est=4.328144729371537, details={'was_impossible': False}),
#  Prediction(uid=17, iid=3267, r_ui=4.0, est=3.8400246206370277, details={'was_impossible': False}),
#  Prediction(uid=481, iid=8529, r_ui=3.5, est=3.7935284220719683, details={'was_impossible': False}),
#  Prediction(uid=380, iid=5617, r_ui=3.5, est=3.3169957398772425, details={'was_impossible': False}),
#  Prediction(uid=547, iid=47, r_ui=4.0, est=4.013233206024058, details={'was_impossible': False}),
#  Prediction(uid=161, iid=454, r_ui=4.0, est=3.4358956582334987, details={'was_impossible': False}),
#  Prediction(uid=500, iid=1923, r_ui=2.0, est=2.590015765543066, details={'was_impossible': False}),
#  Prediction(uid=388, iid=2374, r_ui=3.0, est=3.3594345133171664, details={'was_impossible': False}),
#  Prediction(uid=472, iid=841, r_ui=4.0, est=4.092041303933334, details={'was_impossible': False}),
#  Prediction(uid=599, iid=1148, r_ui=1.5, est=4.535332702205628, details={'was_impossible': False}),
#  Prediction(uid=505, iid=4798, r_ui=3.0, est=3.0543470843182297, details={'was_impossible': False}),
#  Prediction(uid=165, iid=1997, r_ui=2.5, est=3.196128854593686, details={'was_impossible': False}),
#  Prediction(uid=348, iid=593, r_ui=4.0, est=3.753259535288339, details={'was_impossible': False}),
#  Prediction(uid=585, iid=1927, r_ui=5.0, est=3.925502491134659, details={'was_impossible': False}),
#  Prediction(uid=134, iid=5528, r_ui=4.5, est=3.5003567642101046, details={'was_impossible': False}),
#  Prediction(uid=528, iid=3996, r_ui=4.0, est=3.3521448169881616, details={'was_impossible': False}),
#  Prediction(uid=168, iid=237, r_ui=3.0, est=2.8407097209728525, details={'was_impossible': False}),
#  Prediction(uid=620, iid=97921, r_ui=3.0, est=2.987011809747517, details={'was_impossible': False}),
#  Prediction(uid=461, iid=2001, r_ui=3.0, est=2.6409227786790344, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# Напишем нашу функцию, которая принимает на вход id пользователя, а на выходе предлагает ему топ 10 фильмов, которые он еще не видел.

# %%
ratings_f
# Out:
#         userId  movieId  rating   timestamp
# 20           2       10     4.0   835355493
# 21           2       17     5.0   835355681
# 22           2       39     5.0   835355604
# 23           2       47     4.0   835355552
# 24           2       50     4.0   835355586
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [92421 rows x 4 columns]

# %%
title_to_id
# Out:
# {'Toy Story': 1.0,
#  'Jumanji': 2.0,
#  'Grumpier Old Men': 3.0,
#  'Waiting to Exhale': 4.0,
#  'Father of the Bride Part II': 5.0,
#  'Heat': 131274.0,
#  'Sabrina': 915.0,
#  'Tom and Huck': 8.0,
#  'Sudden Death': 9.0,
#  'GoldenEye': 10.0,
#  'The American President': 11.0,
#  'Dracula: Dead and Loving It': 12.0,
#  'Balto': 13.0,
#  'Nixon': 14.0,
#  'Cutthroat Island': 15.0,
#  'Casino': 16.0,
#  'Sense and Sensibility': 165321.0,
#  'Four Rooms': 18.0,
#  'Ace Ventura: When Nature Calls': 19.0,
#  'Money Train': 20.0,
#  'Get Shorty': 21.0,
#  'Copycat': 22.0,
#  'Assassins': 23.0,
#  'Powder': 24.0,
#  'Leaving Las Vegas': 25.0,
#  'Othello': 103683.0,
#  'Now and Then': 27.0,
#  'Persuasion': 164805.0,
#  'The City of Lost Children': 29.0,
#  'Shanghai Triad': 30.0,
#  'Dangerous Minds': 31.0,
#  'Twelve Monkeys': 32.0,
#  'Wings of Courage': 33.0,
#  'Babe': 34.0,
#  'Carrington': 35.0,
#  'Dead Man Walking': 36.0,
#  'Across the Sea of Time': 37.0,
#  'It Takes Two': 131582.0,
#  'Clueless': 39.0,
#  'Cry, the Beloved Country': 123244.0,
#  'Richard III': 89323.0,
#  'Dead Presidents': 42.0,
#  'Restoration': 158390.0,
#  'Mortal Kombat': 44.0,
#  'To Die For': 45.0,
#  'How To Make An American Quilt': 46.0,
#  'Se7en': 47.0,
#  'Pocahontas': 48.0,
#  'When Night Is Falling': 49.0,
#  'The Usual Suspects': 50.0,
#  'Guardian Angel': 51.0,
#  'Mighty Aphrodite': 52.0,
#  'Lamerica': 157357.0,
#  'The Big Green': 54.0,
#  'Georgia': 55.0,
#  'Kids of the Round Table': 56.0,
#  'Home for the Holidays': 143980.0,
#  'The Postman': 1726.0,
#  'The Confessional': 59.0,
#  'The Indian in the Cupboard': 60.0,
#  'Eye for an Eye': 120299.0,
#  "Mr. Holland's Opus": 62.0,
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood": 63.0,
#  'Two If by Sea': 64.0,
#  'Bio-Dome': 65.0,
#  'Lawnmower Man 2: Beyond Cyberspace': 66.0,
#  'Two Bits': 67.0,
#  'French Twist': 68.0,
#  'Friday': 161157.0,
#  'From Dusk Till Dawn': 70.0,
#  'Fair Game': 160768.0,
#  'Kicking and Screaming': 72.0,
#  'Les Miserables': 99562.0,
#  'Bed of Roses': 98437.0,
#  'Big Bully': 75.0,
#  'Screamers': 165797.0,
#  'Nico Icon': 77.0,
#  'The Crossing Guard': 78.0,
#  'The Juror': 79.0,
#  'The White Balloon': 80.0,
#  "Things to Do in Denver When You're Dead": 81.0,
#  "Antonia's Line": 82.0,
#  'Once Upon a Time... When We Were Colored': 83.0,
#  'Last Summer in the Hamptons': 84.0,
#  'Angels and Insects': 85.0,
#  'White Squall': 86.0,
#  'Dunston Checks In': 87.0,
#  'Black Sheep': 82726.0,
#  'Nick of Time': 89.0,
#  'The Journey of August King': 90.0,
#  'Mary Reilly': 92.0,
#  'Vampire in Brooklyn': 93.0,
#  'Beautiful Girls': 94.0,
#  'Broken Arrow': 54121.0,
#  "A Midwinter's Tale": 96.0,
#  'La Haine': 97.0,
#  'Shopping': 98.0,
#  'Heidi Fleiss: Hollywood Madam': 99.0,
#  'City Hall': 100.0,
#  'Bottle Rocket': 101.0,
#  'Mr. Wrong': 102.0,
#  'Unforgettable': 170815.0,
#  'Happy Gilmore': 104.0,
#  'The Bridges of Madison County': 105.0,
#  'Nobody Loves Me': 106.0,
#  'Muppet Treasure Island': 107.0,
#  'Catwalk': 108.0,
#  'Headless Body in Topless Bar': 109.0,
#  'Braveheart': 110.0,
#  'Taxi Driver': 111.0,
#  'Rumble in the Bronx': 112.0,
#  'Before and After': 113.0,
#  "Margaret's Museum": 114.0,
#  'Happiness Is in the Field': 115.0,
#  'Anne Frank Remembered': 116.0,
#  "The Young Poisoner's Handbook": 117.0,
#  'If Lucy Fell': 118.0,
#  'Steal Big Steal Little': 119.0,
#  'Race the Sun': 120.0,
#  'The Boys of St. Vincent': 121.0,
#  'Boomerang': 122.0,
#  'Chungking Express': 123.0,
#  'The Star Maker': 124.0,
#  'Flirting with Disaster': 125.0,
#  'The Neverending Story III: Escape from Fantasia': 126.0,
#  'The Silences of the Palace': 127.0,
#  "Jupiter's Wife": 128.0,
#  'Pie in the Sky': 152930.0,
#  'Angela': 130.0,
#  'Frankie Starlight': 131.0,
#  'Jade': 132.0,
#  'Nueba Yol': 133.0,
#  'Sonic Outlaws': 134.0,
#  'Down Periscope': 135.0,
#  'From the Journals of Jean Seberg': 136.0,
#  'Man of the Year': 48593.0,
#  'The Neon Bible': 138.0,
#  'Target': 114214.0,
#  'Up Close & Personal': 140.0,
#  'The Birdcage': 141.0,
#  'Virgin Mary': 143.0,
#  'The Brothers McMullen': 144.0,
#  'Bad Boys': 132561.0,
#  'The Amazing Panda Adventure': 146.0,
#  'The Basketball Diaries': 147.0,
#  'An Awfully Big Adventure': 148.0,
#  'Amateur': 149.0,
#  'Apollo 13': 150.0,
#  'Rob Roy': 151.0,
#  'The Addiction': 152.0,
#  'Batman Forever': 153.0,
#  'Belle de Jour': 154.0,
#  'Beyond Rangoon': 155.0,
#  'Blue in the Face': 156.0,
#  'Canadian Bacon': 157.0,
#  'Casper': 158.0,
#  'Clockers': 159.0,
#  'Congo': 160.0,
#  'Crimson Tide': 161.0,
#  'Crumb': 162.0,
#  'Desperado': 163.0,
#  'Devil in a Blue Dress': 164.0,
#  'Die Hard: With a Vengeance': 165.0,
#  'The Doom Generation': 166.0,
#  'Feast of July': 167.0,
#  'First Knight': 168.0,
#  'Free Willy 2 - The Adventure Home': 169.0,
#  'Hackers': 170.0,
#  'Jeffrey': 171.0,
#  'Johnny Mnemonic': 172.0,
#  'Judge Dredd': 173.0,
#  'Jury Duty': 174.0,
#  'Kids': 175.0,
#  'Living in Oblivion': 176.0,
#  'Lord of Illusions': 177.0,
#  'Love & Human Remains': 178.0,
#  'Mad Love': 159809.0,
#  'Mallrats': 180.0,
#  'Mighty Morphin Power Rangers: The Movie': 181.0,
#  'Moonlight and Valentino': 182.0,
#  'Mute Witness': 183.0,
#  'Nadja': 184.0,
#  'The Net': 157148.0,
#  'Nine Months': 186.0,
#  'Party Girl': 127650.0,
#  'The Prophecy': 188.0,
#  'Reckless': 71804.0,
#  'Safe': 94405.0,
#  'The Scarlet Letter': 106493.0,
#  'The Show': 139399.0,
#  'Showgirls': 193.0,
#  'Smoke': 194.0,
#  'Something to Talk About': 195.0,
#  'Species': 196.0,
#  'The Stars Fell on Henrietta': 197.0,
#  'Strange Days': 198.0,
#  'The Umbrellas of Cherbourg': 199.0,
#  'The Tie That Binds': 200.0,
#  'Three Wishes': 201.0,
#  'Total Eclipse': 202.0,
#  'To Wong Foo, Thanks for Everything! Julie Newmar': 203.0,
#  'Under Siege 2: Dark Territory': 204.0,
#  'Unstrung Heroes': 205.0,
#  'Unzipped': 206.0,
#  'A Walk in the Clouds': 207.0,
#  'Waterworld': 208.0,
#  "White Man's Burden": 209.0,
#  'Wild Bill': 95804.0,
#  'The Browning Version': 34482.0,
#  'Bushwhacked': 212.0,
#  'Burnt by the Sun': 213.0,
#  'Before the Rain': 214.0,
#  'Before Sunrise': 215.0,
#  'Billy Madison': 216.0,
#  'The Babysitter': 217.0,
#  'Boys on the Side': 218.0,
#  'The Cure': 93330.0,
#  'Castle Freak': 220.0,
#  'Circle of Friends': 222.0,
#  'Clerks': 223.0,
#  'Don Juan DeMarco': 224.0,
#  'Disclosure': 225.0,
#  'Dream Man': 226.0,
#  'Drop Zone': 227.0,
#  'Destiny Turns on the Radio': 228.0,
#  'Death and the Maiden': 229.0,
#  'Dolores Claiborne': 230.0,
#  'Dumb and Dumber': 231.0,
#  'Eat Drink Man Woman': 232.0,
#  'Exotica': 233.0,
#  'Exit to Eden': 234.0,
#  'Ed Wood': 235.0,
#  'French Kiss': 236.0,
#  'Forget Paris': 237.0,
#  'Far from Home: The Adventures of Yellow Dog': 238.0,
#  'A Goofy Movie': 239.0,
#  'Hideaway': 240.0,
#  'Fluke': 151519.0,
#  'Farinelli': 242.0,
#  'Gordy': 243.0,
#  'Gumby: The Movie': 244.0,
#  'The Glass Shield': 245.0,
#  'Hoop Dreams': 246.0,
#  'Heavenly Creatures': 247.0,
#  'Houseguest': 248.0,
#  'Immortal Beloved': 249.0,
#  'Heavyweights': 114353.0,
#  'The Hunted': 6219.0,
#  'I.Q.': 252.0,
#  'Interview with the Vampire': 253.0,
#  'Jefferson in Paris': 254.0,
#  'The Jerky Boys': 255.0,
#  'Junior': 170255.0,
#  'Just Cause': 257.0,
#  "A Kid in King Arthur's Court": 258.0,
#  'Kiss of Death': 41585.0,
#  'Star Wars': 260.0,
#  'Little Women': 7054.0,
#  'A Little Princess': 174235.0,
#  'Ladybird Ladybird': 263.0,
#  "L'Enfer": 264.0,
#  'Like Water for Chocolate': 265.0,
#  'Legends of the Fall': 266.0,
#  'Major Payne': 267.0,
#  'Little Odessa': 268.0,
#  'Mi Vida Loca': 269.0,
#  'Love Affair': 6837.0,
#  'Losing Isaiah': 271.0,
#  'The Madness of King George': 272.0,
#  "Mary Shelley's Frankenstein": 273.0,
#  'Man of the House': 31867.0,
#  'Mixed Nuts': 275.0,
#  'Milk Money': 276.0,
#  'Miracle on 34th Street': 2398.0,
#  'Miami Rhapsody': 278.0,
#  'My Family': 279.0,
#  'Murder in the First': 280.0,
#  "Nobody's Fool": 26577.0,
#  'Nell': 282.0,
#  'New Jersey Drive': 283.0,
#  'New York Cop': 284.0,
#  'Beyond Bedlam': 285.0,
#  'Nemesis 2 - Nebula': 286.0,
#  'Nina Takes a Lover': 287.0,
#  'Natural Born Killers': 288.0,
#  'Only You': 289.0,
#  'Once Were Warriors': 290.0,
#  'Poison Ivy II: Lily': 291.0,
#  'Outbreak': 292.0,
#  'Leon: The Professional': 293.0,
#  'The Perez Family': 294.0,
#  "A Pyromaniac's Love Story": 295.0,
#  'Pulp Fiction': 296.0,
#  'Panther': 297.0,
#  'Pushing Hands': 298.0,
#  'Priest': 86835.0,
#  'Quiz Show': 300.0,
#  'Picture Bride': 301.0,
#  'Queen Margot': 302.0,
#  'The Quick and the Dead': 67068.0,
#  'Roommates': 304.0,
#  'Prêt-à-Porter': 305.0,
#  'Three Colors: Red': 306.0,
#  'Three Colors: Blue': 307.0,
#  'Three Colors: White': 308.0,
#  'Red Firecracker, Green Firecracker': 309.0,
#  'Rent-a-Kid': 310.0,
#  'Relative Fear': 311.0,
#  'Stuart Saves His Family': 312.0,
#  'The Swan Princess': 313.0,
#  'The Secret of Roan Inish': 314.0,
#  'The Specialist': 315.0,
#  'Stargate': 316.0,
#  'The Santa Clause': 317.0,
#  'The Shawshank Redemption': 318.0,
#  'Shallow Grave': 319.0,
#  'Suture': 320.0,
#  'Strawberry and Chocolate': 321.0,
#  'Swimming with Sharks': 322.0,
#  'The Sum of Us': 324.0,
#  'Senior Trip': 325.0,
#  'To Live': 326.0,
#  'Tank Girl': 327.0,
#  'Tales from the Crypt: Demon Knight': 328.0,
#  'Star Trek: Generations': 329.0,
#  'Tales from the Hood': 330.0,
#  'Tom & Viv': 331.0,
#  'Village of the Damned': 2553.0,
#  'Tommy Boy': 333.0,
#  'Vanya on 42nd Street': 334.0,
#  'The Underneath': 122593.0,
#  'The Walking Dead': 8220.0,
#  "What's Eating Gilbert Grape": 337.0,
#  'Virtuosity': 338.0,
#  'While You Were Sleeping': 339.0,
#  'The War': 95604.0,
#  'Double Happiness': 341.0,
#  "Muriel's Wedding": 342.0,
#  'The Baby-Sitters Club': 343.0,
#  'Ace Ventura: Pet Detective': 344.0,
#  'The Adventures of Priscilla, Queen of the Desert': 345.0,
#  'Backbeat': 346.0,
#  'Bitter Moon': 347.0,
#  'Bullets Over Broadway': 348.0,
#  'Clear and Present Danger': 349.0,
#  'The Client': 144504.0,
#  'Corrina, Corrina': 351.0,
#  'Crooklyn': 352.0,
#  'The Crow': 353.0,
#  'Cobb': 354.0,
#  'The Flintstones': 355.0,
#  'Forrest Gump': 356.0,
#  'Four Weddings and a Funeral': 357.0,
#  'Higher Learning': 358.0,
#  'I Like It Like That': 359.0,
#  'I Love Trouble': 124230.0,
#  'It Could Happen to You': 361.0,
#  'The Jungle Book': 137857.0,
#  'The Wonderful, Horrible Life of Leni Riefenstahl': 363.0,
#  'The Lion King': 364.0,
#  'Little Buddha': 365.0,
#  'New Nightmare': 366.0,
#  'The Mask': 156708.0,
#  'Maverick': 368.0,
#  'Mrs. Parker and the Vicious Circle': 369.0,
#  'The Naked Gun 33⅓: The Final Insult': 370.0,
#  'The Paper': 371.0,
#  'Reality Bites': 372.0,
#  'Red Rock West': 373.0,
#  'Ri¢hie Ri¢h': 374.0,
#  'Safe Passage': 375.0,
#  'The River Wild': 376.0,
#  'Speed': 377.0,
#  'Speechless': 378.0,
#  'Timecop': 379.0,
#  'True Lies': 380.0,
#  'When a Man Loves a Woman': 381.0,
#  'Wolf': 148078.0,
#  'Wyatt Earp': 383.0,
#  'Bad Company': 5426.0,
#  'A Man of No Importance': 385.0,
#  'S.F.W.': 386.0,
#  'A Low Down Dirty Shame': 387.0,
#  'Boys Life: Three Stories of Love, Lust, and Liberation': 388.0,
#  'Colonel Chabert': 389.0,
#  'Faster, Pussycat! Kill! Kill!': 390.0,
#  "Jason's Lyric": 391.0,
#  'The Secret Adventures of Tom Thumb': 392.0,
#  'Street Fighter': 393.0,
#  'Coldblooded': 394.0,
#  'Desert Winds': 395.0,
#  'Fall Time': 396.0,
#  'The Fear': 397.0,
#  'Frank and Ollie': 398.0,
#  'Girl in the Cadillac': 399.0,
#  'Homage': 400.0,
#  'Mirage': 175451.0,
#  'Open Season': 48414.0,
#  'Dos Crímenes': 403.0,
#  'Brother Minister: The Assassination of Malcolm X': 404.0,
#  'Highlander: The Final Dimension': 405.0,
#  'Federal Hill': 406.0,
#  'In the Mouth of Madness': 407.0,
#  '8 Seconds': 408.0,
#  'Above the Rim': 409.0,
#  'Addams Family Values': 410.0,
#  'Martin Lawrence: You So Crazy': 411.0,
#  'The Age of Innocence': 98027.0,
#  'Airheads': 413.0,
#  'The Air Up There': 414.0,
#  'Another Stakeout': 415.0,
#  'Bad Girls': 103523.0,
#  'Barcelona': 417.0,
#  'Being Human': 418.0,
#  'The Beverly Hillbillies': 419.0,
#  'Beverly Hills Cop III': 420.0,
#  'Black Beauty': 8929.0,
#  'Blink': 422.0,
#  'Blown Away': 91112.0,
#  'Blue Chips': 424.0,
#  'Blue Sky': 425.0,
#  'Body Snatchers': 426.0,
#  'Boxing Helena': 427.0,
#  'A Bronx Tale': 428.0,
#  'Cabin Boy': 429.0,
#  'Calendar Girl': 430.0,
#  "Carlito's Way": 431.0,
#  "City Slickers II: The Legend of Curly's Gold": 432.0,
#  'Clean Slate': 433.0,
#  'Cliffhanger': 434.0,
#  'Coneheads': 435.0,
#  'Color of Night': 436.0,
#  'Cops & Robbersons': 437.0,
#  'The Cowboy Way': 438.0,
#  'Dangerous Game': 439.0,
#  'Dave': 440.0,
#  'Dazed and Confused': 441.0,
#  'Demolition Man': 442.0,
#  'The Endless Summer 2': 443.0,
#  'Even Cowgirls Get the Blues': 444.0,
#  'Fatal Instinct': 445.0,
#  'Farewell My Concubine': 446.0,
#  'The Favor': 447.0,
#  'Fearless': 46322.0,
#  'Fear of a Black Hat': 449.0,
#  'With Honors': 450.0,
#  'Flesh and Bone': 451.0,
#  "Widows' Peak": 452.0,
#  'For Love or Money': 168364.0,
#  'The Firm': 95624.0,
#  'Free Willy': 455.0,
#  'Fresh': 158735.0,
#  'The Fugitive': 55854.0,
#  'Geronimo: An American Legend': 458.0,
#  'The Getaway': 8016.0,
#  'Getting Even with Dad': 460.0,
#  'Go Fish': 461.0,
#  'A Good Man in Africa': 462.0,
#  'Guilty as Sin': 463.0,
#  'Hard Target': 464.0,
#  'Heaven & Earth': 465.0,
#  'Hot Shots! Part Deux': 466.0,
#  'Live Nude Girls': 467.0,
#  'The Englishman Who Went Up a Hill But Came Down a Mountain': 468.0,
#  'The House of the Spirits': 469.0,
#  'House Party 3': 470.0,
#  'The Hudsucker Proxy': 471.0,
#  "I'll Do Anything": 472.0,
#  'In the Army Now': 473.0,
#  'In the Line of Fire': 474.0,
#  'In the Name of the Father': 475.0,
#  'The Inkwell': 476.0,
#  "What's Love Got to Do with It": 477.0,
#  'Jimmy Hollywood': 478.0,
#  'Judgment Night': 479.0,
#  'Jurassic Park': 480.0,
#  'Kalifornia': 481.0,
#  'Killing Zoe': 482.0,
#  'King of the Hill': 483.0,
#  'Lassie': 47805.0,
#  'Last Action Hero': 485.0,
#  'Life With Mikey': 486.0,
#  'Lightning Jack': 487.0,
#  'M. Butterfly': 488.0,
#  'Made in America': 489.0,
#  'Malice': 490.0,
#  'The Man without a Face': 491.0,
#  'Manhattan Murder Mystery': 492.0,
#  'Menace II Society': 493.0,
#  'Executive Decision': 494.0,
#  'In the Realm of the Senses': 495.0,
#  'What Happened Was...': 496.0,
#  'Much Ado About Nothing': 171905.0,
#  'Mr. Jones': 118922.0,
#  'Mr. Wonderful': 499.0,
#  'Mrs. Doubtfire': 500.0,
#  'Naked': 163953.0,
#  'The Next Karate Kid': 502.0,
#  'The New Age': 503.0,
#  'No Escape': 140713.0,
#  'North': 79505.0,
#  'Orlando': 506.0,
#  'A Perfect World': 507.0,
#  'Philadelphia': 508.0,
#  'The Piano': 509.0,
#  'Poetic Justice': 510.0,
#  'The Program': 142765.0,
#  'The Puppet Masters': 512.0,
#  'Radioland Murders': 513.0,
#  'The Ref': 514.0,
#  'The Remains of the Day': 515.0,
#  'Renaissance Man': 516.0,
#  'Rising Sun': 517.0,
#  'The Road to Wellville': 518.0,
#  'RoboCop 3': 519.0,
#  'Robin Hood: Men in Tights': 520.0,
#  'Romeo Is Bleeding': 521.0,
#  'Romper Stomper': 522.0,
#  'Ruby in Paradise': 523.0,
#  'Rudy': 524.0,
#  'The Saint of Fort Washington': 525.0,
#  'Savage Nights': 526.0,
#  "Schindler's List": 527.0,
#  'The Scout': 528.0,
#  'Searching for Bobby Fischer': 529.0,
#  'Second Best': 530.0,
#  'The Secret Garden': 166179.0,
#  'Serial Mom': 532.0,
#  'The Shadow': 533.0,
#  'Shadowlands': 534.0,
#  'Short Cuts': 535.0,
#  'A Simple Twist of Fate': 536.0,
#  'Sirens': 537.0,
#  'Six Degrees of Separation': 538.0,
#  'Sleepless in Seattle': 539.0,
#  'Sliver': 540.0,
#  'Blade Runner': 541.0,
#  'Son in Law': 542.0,
#  'So I Married an Axe Murderer': 543.0,
#  'Striking Distance': 544.0,
#  'Harem': 545.0,
#  'Super Mario Bros.': 546.0,
#  'Surviving the Game': 547.0,
#  'Terminal Velocity': 548.0,
#  'Thirty Two Short Films About Glenn Gould': 549.0,
#  'Threesome': 550.0,
#  'The Nightmare Before Christmas': 551.0,
#  'The Three Musketeers': 92843.0,
#  'Tombstone': 553.0,
#  'Trial by Jury': 554.0,
#  'True Romance': 555.0,
#  'The War Room': 556.0,
#  'The Pagemaster': 558.0,
#  'Paris, France': 559.0,
#  'The Beans of Egypt, Maine': 560.0,
#  'Killer': 90935.0,
#  'Welcome to the Dollhouse': 562.0,
#  'Germinal': 563.0,
#  'Chasers': 564.0,
#  'Cronos': 565.0,
#  'Naked in New York': 566.0,
#  'Kika': 567.0,
#  'Bhaji on the Beach': 568.0,
#  'Little Big League': 569.0,
#  'The Slingshot': 570.0,
#  'Wide Eyed and Legless': 571.0,
#  'Foreign Student': 572.0,
#  'Ciao, Professore!': 573.0,
#  'Spanking the Monkey': 574.0,
#  'The Little Rascals': 575.0,
#  'À la mode': 576.0,
#  'Andre': 577.0,
#  'The Escort': 140301.0,
#  'Princess Caraboo': 580.0,
#  'The Celluloid Closet': 581.0,
#  'Café au Lait': 582.0,
#  'Dear Diary': 583.0,
#  "I Don't Want to Talk About It": 584.0,
#  'The Brady Bunch Movie': 585.0,
#  'Home Alone': 586.0,
#  'Ghost': 172421.0,
#  'Aladdin': 119061.0,
#  'Terminator 2: Judgment Day': 589.0,
#  'Dances with Wolves': 590.0,
#  'Tough and Deadly': 591.0,
#  'Batman': 26152.0,
#  'The Silence of the Lambs': 593.0,
#  'Snow White and the Seven Dwarfs': 594.0,
#  'Beauty and the Beast': 168366.0,
#  'Pinocchio': 126693.0,
#  'Pretty Woman': 597.0,
#  'Window to Paris': 598.0,
#  'The Wild Bunch': 599.0,
#  'Love and a .45': 600.0,
#  "The Wooden Man's Bride": 601.0,
#  'A Great Day in Harlem': 602.0,
#  'Bye Bye Love': 603.0,
#  'One Fine Day': 605.0,
#  'Candyman: Farewell to the Flesh': 606.0,
#  'Century': 607.0,
#  'Fargo': 608.0,
#  'Homeward Bound II: Lost in San Francisco': 609.0,
#  'Heavy Metal': 610.0,
#  'Hellraiser: Bloodline': 611.0,
#  'The Pallbearer': 612.0,
#  'Jane Eyre': 174849.0,
#  'Loaded': 131628.0,
#  'Bread and Chocolate': 615.0,
#  'The Aristocats': 616.0,
#  'The Flower of My Secret': 617.0,
#  'Two Much': 618.0,
#  'Ed': 619.0,
#  'Scream of Stone': 620.0,
#  'My Favorite Season': 621.0,
#  'A Modern Affair': 623.0,
#  'Condition Red': 624.0,
#  'Halfaouine: Boy of the Terraces': 625.0,
#  'A Thin Line Between Love and Hate': 626.0,
#  'The Last Supper': 627.0,
#  'Primal Fear': 628.0,
#  'Rude': 629.0,
#  'Carried Away': 630.0,
#  'All Dogs Go to Heaven 2': 631.0,
#  'Land and Freedom': 632.0,
#  'Denise Calls Up': 633.0,
#  'Theodore Rex': 634.0,
#  'A Family Thing': 635.0,
#  'Frisk': 636.0,
#  'Sgt. Bilko': 637.0,
#  'Jack & Sarah': 638.0,
#  'Girl 6': 639.0,
#  'Diabolique': 7116.0,
#  'Little Indian, Big City': 641.0,
#  'Roula': 642.0,
#  'Peanuts – Die Bank zahlt alles': 643.0,
#  'Happy Weekend': 644.0,
#  'Nelly and Monsieur Arnaud': 645.0,
#  'Courage Under Fire': 647.0,
#  'Mission: Impossible': 648.0,
#  'Cold Fever': 649.0,
#  'Moll Flanders': 650.0,
#  'The Superwife': 651.0,
#  '301, 302': 652.0,
#  'DragonHeart': 653.0,
#  'Und keiner weint mir nach': 654.0,
#  "My Mother's Courage": 655.0,
#  'Eddie': 656.0,
#  'Yankee Zulu': 657.0,
#  "Billy's Holiday": 658.0,
#  'Purple Noon': 659.0,
#  'August': 112391.0,
#  'James and the Giant Peach': 661.0,
#  'Fear': 153378.0,
#  'Kids in the Hall: Brain Candy': 663.0,
#  'Faithful': 664.0,
#  'Underground': 146564.0,
#  'All Things Fair': 666.0,
#  'Bloodsport II': 667.0,
#  'Pather Panchali': 668.0,
#  'The World of Apu': 670.0,
#  'Mystery Science Theater 3000: The Movie': 671.0,
#  'Tarantella': 672.0,
#  'Space Jam': 673.0,
#  'Barbarella': 674.0,
#  'Hostile Intentions': 675.0,
#  'They Bite': 676.0,
#  'Some Folks Call It a Sling Blade': 678.0,
#  'The Run of the Country': 679.0,
#  'Alphaville': 680.0,
#  'Coup de Torchon': 681.0,
#  'Tigrero: A Film That Was Never Made': 682.0,
#  'The Eye of Vichy': 683.0,
#  'Windows': 684.0,
#  "It's My Party": 685.0,
#  'Country Life': 687.0,
#  'Operation Dumbo Drop': 688.0,
#  'The Promise': 173729.0,
#  'Mrs. Winterbourne': 691.0,
#  'Solo': 135711.0,
#  'Under The Domim Tree': 693.0,
#  'The Substitute': 139727.0,
#  'True Crime': 2561.0,
#  'Butterfly Kiss': 173645.0,
#  'Feeling Minnesota': 697.0,
#  'Delta of Venus': 698.0,
#  'To Cross the Rubicon': 699.0,
#  'Angus': 700.0,
#  'Priest Daens': 701.0,
#  'Faces': 702.0,
#  'Boys': 130628.0,
#  'The Quest': 704.0,
#  'Cosi': 705.0,
#  'Sunset Park': 706.0,
#  'Mulholland Falls': 707.0,
#  'The Truth About Cats & Dogs': 708.0,
#  'Oliver & Company': 709.0,
#  'Celtic Pride': 710.0,
#  'Flipper': 8850.0,
#  'Captives': 712.0,
#  'Of Love and Shadows': 713.0,
#  'Dead Man': 714.0,
#  'The Horseman on the Roof': 715.0,
#  'Switchblade Sisters': 716.0,
#  'Mouth to Mouth': 46478.0,
#  'The Visitors': 148398.0,
#  'Multiplicity': 719.0,
#  'The Haunted World of Edward D. Wood, Jr.': 722.0,
#  'Two Friends': 155382.0,
#  'The Craft': 724.0,
#  'The Great White Hype': 725.0,
#  'Last Dance': 726.0,
#  'War Stories Our Mother Never Told Us': 727.0,
#  'Cold Comfort Farm': 728.0,
#  'Institute Benjamenta, or This Dream People Call Human Life': 729.0,
#  "Heaven's Prisoners": 731.0,
#  'Original Gangstas': 732.0,
#  'The Rock': 733.0,
#  'Getting Away with Murder': 734.0,
#  'Cemetery Man': 735.0,
#  'Twister': 7781.0,
#  'Barb Wire': 737.0,
#  'Le Garçu': 738.0,
#  'Honeymoon': 163120.0,
#  'Ghost in the Shell': 168612.0,
#  'Thinner': 742.0,
#  'Spy Hard': 743.0,
#  'Brothers in Trouble': 744.0,
#  'A Close Shave': 745.0,
#  'Force of Evil': 746.0,
#  'The Stupids': 747.0,
#  'The Arrival': 748.0,
#  'The Man from Down Under': 749.0,
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb': 750.0,
#  'Careful': 751.0,
#  'Vermont Is for Lovers': 752.0,
#  'A Month by the Lake': 753.0,
#  'Gold Diggers: The Secret of Bear Mountain': 754.0,
#  'Kim': 755.0,
#  'Carmen Miranda: Bananas Is My Business': 756.0,
#  'Ashes of Time': 757.0,
#  'The Jar': 758.0,
#  'Maya Lin: A Strong Clear Vision': 759.0,
#  'Stalingrad': 123044.0,
#  'The Phantom': 167886.0,
#  'Striptease': 762.0,
#  'The Last of the High Kings': 763.0,
#  'Heavy': 764.0,
#  'Jack': 163557.0,
#  'I Shot Andy Warhol': 766.0,
#  'The Grass Harp': 767.0,
#  "Someone Else's America": 768.0,
#  'Life is Rosy': 771.0,
#  'Quartier Mozart': 772.0,
#  'Touki Bouki': 773.0,
#  "God's Gift": 774.0,
#  'Spirits of the Dead': 775.0,
#  'Babyfever': 776.0,
#  "Pharaoh's  Army": 777.0,
#  'Trainspotting': 778.0,
#  'Til There Was You': 779.0,
#  'Independence Day': 780.0,
#  'Stealing Beauty': 781.0,
#  'The Fan': 5655.0,
#  'The Hunchback of Notre Dame': 25746.0,
#  'The Cable Guy': 784.0,
#  'Kingpin': 785.0,
#  'Eraser': 786.0,
#  'The Gate of Heavenly Peace': 787.0,
#  'The Nutty Professor': 2136.0,
#  'I, the Worst of All': 789.0,
#  'An Unforgettable Summer': 790.0,
#  'A Hungarian Fairy Tale': 792.0,
#  'My Life and Times With Antonin Artaud': 793.0,
#  'Midnight Dancers': 794.0,
#  'Somebody to Love': 795.0,
#  'A Very Natural Thing': 796.0,
#  'The Old Lady Who Walked in the Sea': 797.0,
#  'Daylight': 109951.0,
#  'The Frighteners': 799.0,
#  'Lone Star': 800.0,
#  'Harriet the Spy': 801.0,
#  'Phenomenon': 802.0,
#  'Walking and Talking': 803.0,
#  "She's the One": 804.0,
#  'A Time to Kill': 805.0,
#  'American Buffalo': 806.0,
#  'Rendezvous in Paris': 807.0,
#  'Alaska': 808.0,
#  'Fled': 809.0,
#  'Kazaam': 810.0,
#  'Magic Hunter': 812.0,
#  'Larger Than Life': 813.0,
#  'A Boy Called Hate': 814.0,
#  'Power 98': 815.0,
#  'Two Deaths': 816.0,
#  'A Very Brady Sequel': 818.0,
#  'Stefano Quantestorie': 819.0,
#  'Death in the Garden': 820.0,
#  'Hedd Wyn': 822.0,
#  'La Collectionneuse': 823.0,
#  'Kaspar Hauser': 824.0,
#  'Regular Guys': 825.0,
#  'Diebinnen': 826.0,
#  'The Convent': 4997.0,
#  'The Adventures of Pinocchio': 828.0,
#  "Joe's Apartment": 829.0,
#  'The First Wives Club': 830.0,
#  'Stonewall': 151557.0,
#  'Ransom': 7197.0,
#  'High School High': 833.0,
#  'Phat Beach': 834.0,
#  'Foxfire': 102995.0,
#  'Chain Reaction': 69339.0,
#  'Matilda': 134513.0,
#  'Emma': 164819.0,
#  'The Crow: City of Angels': 839.0,
#  'House Arrest': 840.0,
#  'Eyes Without a Face': 841.0,
#  'Bordello of Blood': 842.0,
#  'Lotto Land': 843.0,
#  'The Story of Xinghua': 844.0,
#  'The Day the Sun Turned Cold': 845.0,
#  'Flirt': 846.0,
#  'The Big Squeeze': 847.0,
#  'The Spitfire Grill': 848.0,
#  'Escape from L.A.': 849.0,
#  'Cyclo': 850.0,
#  'Basquiat': 851.0,
#  'Tin Cup': 852.0,
#  'Dingo': 853.0,
#  'The Ballad of Narayama': 2512.0,
#  'Every Other Weekend': 855.0,
#  'Mille bolle blu': 856.0,
#  'Crows and Sparrows': 857.0,
#  'The Godfather': 858.0,
#  'Maybe... Maybe Not': 860.0,
#  'Police Story 3: Supercop': 861.0,
#  'Manny & Lo': 862.0,
#  'Wife': 864.0,
#  'Small Faces': 865.0,
#  'Bound': 136648.0,
#  'Carpool': 867.0,
#  'Death in Brunswick': 868.0,
#  'Kansas City': 869.0,
#  "Gone Fishin'": 870.0,
#  "Lover's Knot": 871.0,
#  "Vive L'Amour": 872.0,
#  'Shadow of Angels': 873.0,
#  'Killer: A Journal of Murder': 874.0,
#  'Nothing to Lose': 7048.0,
#  'Project S': 876.0,
#  'Girls Town': 173053.0,
#  'Bye-Bye': 878.0,
#  'The Relic': 879.0,
#  'The Island of Dr. Moreau': 78967.0,
#  'First Kid': 881.0,
#  'The Trigger Effect': 882.0,
#  'Sweet Nothing': 884.0,
#  'Bogus': 885.0,
#  'Bulletproof': 136558.0,
#  'Talk of Angels': 887.0,
#  'The Land Before Time III: The Time of the Great Giving': 888.0,
#  '1-900': 889.0,
#  'Baton Rouge': 890.0,
#  'Halloween: The Curse of Michael Myers': 891.0,
#  'Twelfth Night': 892.0,
#  'Mother Night': 893.0,
#  'Liebelei': 894.0,
#  'Venice': 895.0,
#  'Wild Reeds': 896.0,
#  'For Whom the Bell Tolls': 897.0,
#  'The Philadelphia Story': 898.0,
#  "Singin' in the Rain": 899.0,
#  'An American in Paris': 900.0,
#  'Funny Face': 901.0,
#  "Breakfast at Tiffany's": 902.0,
#  'Vertigo': 903.0,
#  'Rear Window': 166771.0,
#  'It Happened One Night': 905.0,
#  'Gaslight': 25852.0,
#  'The Gay Divorcee': 907.0,
#  'North by Northwest': 908.0,
#  'The Apartment': 6789.0,
#  'Some Like It Hot': 910.0,
#  'Charade': 911.0,
#  'Casablanca': 912.0,
#  'The Maltese Falcon': 8228.0,
#  'My Fair Lady': 914.0,
#  'Roman Holiday': 916.0,
#  'The Little Princess': 917.0,
#  'Meet Me in St. Louis': 918.0,
#  'The Wizard of Oz': 79287.0,
#  'Gone with the Wind': 920.0,
#  'My Favorite Year': 921.0,
#  'Sunset Boulevard': 922.0,
#  'Citizen Kane': 923.0,
#  '2001: A Space Odyssey': 924.0,
#  'Golden Earrings': 925.0,
#  'All About Eve': 926.0,
#  'The Women': 61361.0,
#  'Rebecca': 928.0,
#  'Foreign Correspondent': 929.0,
#  'Notorious': 65810.0,
#  'Spellbound': 149508.0,
#  'An Affair to Remember': 932.0,
#  'To Catch a Thief': 933.0,
#  'Father of the Bride': 6944.0,
#  'The Band Wagon': 935.0,
#  'Ninotchka': 936.0,
#  'Love in the Afternoon': 43497.0,
#  'Gigi': 89939.0,
#  'The Reluctant Debutante': 939.0,
#  'The Adventures of Robin Hood': 940.0,
#  'The Mark of Zorro': 59945.0,
#  'Laura': 942.0,
#  'The Ghost and Mrs. Muir': 943.0,
#  'Lost Horizon': 49759.0,
#  'Top Hat': 945.0,
#  'To Be or Not to Be': 26491.0,
#  'My Man Godfrey': 3096.0,
#  'Giant': 71677.0,
#  'East of Eden': 949.0,
#  'The Thin Man': 950.0,
#  'His Girl Friday': 951.0,
#  'Around the World in Eighty Days': 952.0,
#  "It's a Wonderful Life": 953.0,
#  'Mr. Smith Goes to Washington': 954.0,
#  'Bringing Up Baby': 955.0,
#  'Penny Serenade': 956.0,
#  'Lady of Burlesque': 958.0,
#  'Of Human Bondage': 959.0,
#  'Angel on My Shoulder': 960.0,
#  'Little Lord Fauntleroy': 121279.0,
#  'They Made Me a Criminal': 962.0,
#  'The Inspector General': 963.0,
#  'Angel and the Badman': 964.0,
#  'The 39 Steps': 122787.0,
#  'A Walk in the Sun': 966.0,
#  'The Outlaw': 967.0,
#  'Night of the Living Dead': 8225.0,
#  'The African Queen': 969.0,
#  'Beat the Devil': 970.0,
#  'Cat on a Hot Tin Roof': 971.0,
#  'The Last Time I Saw Paris': 972.0,
#  'Meet John Doe': 973.0,
#  'Algiers': 974.0,
#  'Something to Sing About': 165027.0,
#  'A Farewell to Arms': 976.0,
#  'Moonlight Murder': 977.0,
#  'Nothing Personal': 89638.0,
#  'Yes, Madam': 980.0,
#  'Dangerous Ground': 981.0,
#  'Picnic': 172629.0,
#  'Madagascar Skin': 983.0,
#  'The Pompatus of Love': 984.0,
#  'Small Wonders': 985.0,
#  'Fly Away Home': 986.0,
#  'Bliss': 102483.0,
#  'Grace of My Heart': 988.0,
#  'Brother of Sleep': 989.0,
#  'Maximum Risk': 990.0,
#  'Michael Collins': 991.0,
#  "The Rich Man's Wife": 992.0,
#  'Infinity': 993.0,
#  'Big Night': 994.0,
#  'Last Man Standing': 125071.0,
#  'Caught': 151819.0,
#  'Set It Off': 998.0,
#  '2 Days in the Valley': 999.0,
#  'Curdled': 1000.0,
#  "L'associé": 1001.0,
#  "Ed's Next Move": 1002.0,
#  'Extreme Measures': 1003.0,
#  'The Glimmer Man': 1004.0,
#  'D3: The Mighty Ducks': 1005.0,
#  'The Chamber': 1006.0,
#  'The Apple Dumpling Gang': 1007.0,
#  'Davy Crockett, King of the Wild Frontier': 1008.0,
#  'Escape to Witch Mountain': 164859.0,
#  'The Love Bug': 150554.0,
#  'Herbie Rides Again': 1011.0,
#  'Old Yeller': 1012.0,
#  'The Parent Trap': 2059.0,
#  'Pollyanna': 158958.0,
#  'Homeward Bound: The Incredible Journey': 1015.0,
#  'The Shaggy Dog': 44399.0,
#  'Swiss Family Robinson': 1017.0,
#  'That Darn Cat!': 1018.0,
#  '20,000 Leagues Under the Sea': 114130.0,
#  'Cool Runnings': 1020.0,
#  'Angels in the Outfield': 110597.0,
#  'Cinderella': 176143.0,
#  'Winnie the Pooh and the Blustery Day': 1023.0,
#  'The Three Caballeros': 1024.0,
#  'The Sword in the Stone': 1025.0,
#  'So Dear to My Heart': 1026.0,
#  'Robin Hood: Prince of Thieves': 1027.0,
#  'Mary Poppins': 1028.0,
#  'Dumbo': 1029.0,
#  "Pete's Dragon": 160573.0,
#  ...}

# %%
def pred_user_rating(ui):
    if ui in ratings_f.userId.unique():
        ui_list = ratings_f.groupby('userId')['movieId'].apply(list)[ui]
        #Из таблицы ratings_f создайте list фильмов, которые оценил конкретный пользователь
        d =  {value: key for (key, value) in title_to_id.items() if value not in [float(i) for i in ui_list]}
        #Создайте инвертированный словарь title_to_id, но только для тех фильмов, которые ui не видел. То есть исключите
        #из списка фильмов множество ui_list. Инвертированный - то есть ключи стали значениями, а значения - ключами
        
        #С помощью нашей обученной модели, проставим предсказанные рейтинги фильмам, которые пользователь еще не видел.
        predictedL = []
        for i, j in d.items():     
            predicted = algorithm.predict(ui, i)
            predictedL.append((j, predicted[3])) 
        pdf = pd.DataFrame(predictedL, columns = ['movies', 'ratings'])
        #Создайте датафрейм из массива predictedL с колонками ['movies', 'ratings']
        
        pdf = pdf.sort_values(by = ['ratings'], ascending=False)
        #Отсортируйте таблицу по колонке ratings, от большего - к меньшему
        
        print(pdf)
        
        pdf.set_index('movies', inplace=True)    
        return pdf.head(10)        
    else:
        print("Пользователь не найден в списке!")
        return None

# %%
user_id = 2
predicted_ratings = pred_user_rating(user_id)
# Out:
#                                              movies   ratings
# 6822  The Lord of the Rings: The Return of the King  4.373368
# 1068                                Cinema Paradiso  4.343784
# 823                                      Casablanca  4.299762
# 902                                       Big Night  4.297117
# 836                                   All About Eve  4.293933
# ...                                             ...       ...
# 330                                     Ri¢hie Ri¢h  2.232222
# 165         Mighty Morphin Power Rangers: The Movie  2.191710
# 1371                                       Anaconda  2.175003
# 3600                                     Hollow Man  2.144563
# 3373                              Battlefield Earth  2.097691
#
# [42216 rows x 2 columns]

# %%
predicted_ratings
# Out:
#                                                 ratings
# movies
# The Lord of the Rings: The Return of the King  4.373368
# Cinema Paradiso                                4.343784
# Casablanca                                     4.299762
# Big Night                                      4.297117
# All About Eve                                  4.293933
# The African Queen                              4.287486
# Patton                                         4.284053
# Memento                                        4.253047
# Raging Bull                                    4.252965
# Ran                                            4.243465
